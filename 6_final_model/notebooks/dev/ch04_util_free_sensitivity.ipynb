# %% [markdown]
# # CH4 utilization-free sensitivity (CTS-2026-0235R2)
#
# Lightweight driver. The full runnable logic lives in the paired script:
# `ch04_util_free_sensitivity.py` (same folder).
#
# ## Run
# ```powershell
# cd C:\Projects\pgx-analysis
# .\.venv\Scripts\python.exe 6_final_model\notebooks\dev\ch04_util_free_sensitivity.py
# ```
#
# ## Outputs
# - `6_final_model/outputs/non_opioid_ed/65_74_util_free/`
# - `8_ffa_analysis/outputs/non_opioid_ed/65_74_util_free_sensitivity/`
# - `manuscript/data/supplementary/ch04_util_free_sensitivity/`
#
# Compares holdout AUPRC, top drug SHAP overlap, and published pair/triplet persistence after dropping utilization-derived features.

# %%
# %run ./ch04_util_free_sensitivity.py
