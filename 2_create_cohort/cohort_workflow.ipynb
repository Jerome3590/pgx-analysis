# %% [markdown]
# # Cohort Creation Workflow
#
# This notebook provides a complete workflow for clearing and rebuilding cohorts.
#
# ## Workflow Steps
#
# 1. **Configuration**: Set up paths, Python binaries, and cohort parameters
# 2. **Cleanup**: Clear existing cohort data (S3 and local)
# 3. **Cohort Creation**: Build cohorts with time-windowed HCG event logic
# 4. **Verification**: Verify cohorts were created successfully
#
# ## Navigation
#
# - **Section A**: Configuration and Setup
# - **Section B**: Cleanup Existing Cohorts
# - **Section C**: Create Cohorts
# - **Section D**: Verify Cohort Creation
#
# ---
#
# **Note**: This notebook follows the same structure as the Step 3b Feature Importance EDA workflow notebooks for consistency.

# %% [markdown]
# ## A. Configuration and Setup

# %%
import sys
import os
from pathlib import Path
import subprocess
import boto3
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set project root
PROJECT_ROOT = Path('/home/pgx3874/pgx-analysis')  # Update for your EC2 path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Jupyter environment Python path (update if different)
PYTHON_BIN = Path('/home/pgx3874/jupyter-env/bin/python3.11')  # Full path to Jupyter Python
if not PYTHON_BIN.exists():
    # Fallback to sys.executable if custom path doesn't exist
    PYTHON_BIN = Path(sys.executable)
    print(f"⚠️  Custom Python path not found, using: {PYTHON_BIN}")

# Import project utilities
from py_helpers.constants import age_band_to_fname

# Configuration
# Cohorts to create
COHORTS = [
    "opioid_ed",      # OPIOID_ED cohort (F11.20 target)
    "non_opioid_ed"   # POLYPHARMACY COHORT (time-windowed HCG target)
]

# Age bands for each cohort
AGE_BANDS = {
    "opioid_ed": ["13-24", "25-44", "45-54", "55-64"],
    "non_opioid_ed": ["65-74", "75-84", "85-94"]
}

# Event years to process
EVENT_YEARS = [2016, 2017, 2018, 2019]

# Time window for polypharmacy cohort (non_opioid_ed)
# Options: 7, 14, 21, 30, 45 days (default: 14)
TIME_WINDOW_DAYS = 14

# S3 bucket
S3_BUCKET = "pgxdatalake"
S3_REPO_BUCKET = "pgx-repository"

# Output directories
LOG_DIR = PROJECT_ROOT / "2_create_cohort" / "logs"
LOG_DIR.mkdir(parents=True, exist_ok=True)

# Always use NVMe spill directory for DuckDB
os.environ["DUCKDB_TMP_DIRECTORY"] = "/mnt/nvme/duckdb_tmp"

# Two-job plan: treat total workers as 2 for memory calc
os.environ["PGX_TOTAL_WORKERS"] = "2"

# Optional: enable DuckDB profiling (only if debugging performance)
# os.environ["PGX_ENABLE_DUCKDB_PROFILING"] = "1"


print(f"✅ Configuration loaded")
print(f"   Project Root: {PROJECT_ROOT}")
print(f"   Python Binary: {PYTHON_BIN}")
print(f"   Cohorts: {COHORTS}")
print(f"   Time Window (polypharmacy): {TIME_WINDOW_DAYS} days")
print(f"   Event Years: {EVENT_YEARS}")
print(f"   Log Directory: {LOG_DIR}")
# Out:
# ✅ Configuration loaded
#    Project Root: /home/pgx3874/pgx-analysis
#    Python Binary: /home/pgx3874/jupyter-env/bin/python3.11
#    Cohorts: ['opioid_ed', 'non_opioid_ed']
#    Time Window (polypharmacy): 14 days
#    Event Years: [2016, 2017, 2018, 2019]
#    Log Directory: /home/pgx3874/pgx-analysis/2_create_cohort/logs

# %% [markdown]
# ## B. Cleanup Existing Cohorts
#
# **Warning**: This will delete existing cohort data from S3 and local storage.
#
# This step clears:
# - Step 2: Cohort parquet files (S3 and local)
# - Step 3b: Feature importance outputs
# - Step 4a: Model data
# - Step 6: Trained models
# - Checkpoints (optional)

# %%
# Check what exists before cleanup
s3_client = boto3.client('s3')

print("📊 Checking existing cohort data in S3...")
print("=" * 60)

cohort_paths = [
    f"gold/cohorts/cohort_name={cohort}/" for cohort in COHORTS
]

for cohort_path in cohort_paths:
    try:
        response = s3_client.list_objects_v2(
            Bucket=S3_BUCKET,
            Prefix=cohort_path,
            MaxKeys=10
        )
        
        if 'Contents' in response:
            count = len(response['Contents'])
            total = response.get('KeyCount', count)
            print(f"   {cohort_path}: {count} objects found (showing first 10)")
        else:
            print(f"   {cohort_path}: No objects found")
    except Exception as e:
        print(f"   {cohort_path}: Error checking - {e}")

print("=" * 60)
# Out:
# 📊 Checking existing cohort data in S3...
# ============================================================
#    gold/cohorts/cohort_name=opioid_ed/: No objects found
#    gold/cohorts/cohort_name=non_opioid_ed/: 10 objects found (showing first 10)
# ============================================================

# %%
# Run cleanup script
# Options:
#   --skip-checkpoints: Keep checkpoints
#   --skip-s3: Only delete local files
#   --skip-local: Only delete S3 files
#   --yes: Auto-confirm (skip interactive prompt)

SKIP_CHECKPOINTS = False  # Set to True to keep checkpoints
SKIP_S3 = False           # Set to True to skip S3 deletion
SKIP_LOCAL = False        # Set to True to skip local deletion
AUTO_CONFIRM = True       # Set to True to skip confirmation prompt (for notebook use)

cleanup_script = PROJECT_ROOT / "2_create_cohort" / "cleanup_cohort_data.sh"

if not cleanup_script.exists():
    print(f"❌ Cleanup script not found: {cleanup_script}")
    print("   Skipping cleanup step")
else:
    print("🧹 Running cleanup script...")
    print(f"   Script: {cleanup_script}")
    
    # Build command
    cmd = ["bash", str(cleanup_script)]
    
    if SKIP_CHECKPOINTS:
        cmd.append("--skip-checkpoints")
    if SKIP_S3:
        cmd.append("--skip-s3")
    if SKIP_LOCAL:
        cmd.append("--skip-local")
    if AUTO_CONFIRM:
        cmd.append("--yes")  # Skip confirmation prompt for notebook use
    
    print(f"   Command: {' '.join(cmd)}")
    if AUTO_CONFIRM:
        print(f"   ⚠️  Auto-confirmation enabled (--yes flag)")
    
    result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), text=True)
    
    if result.returncode == 0:
        print(f"\n✅ Cleanup completed successfully")
    else:
        print(f"\n❌ Cleanup failed with return code {result.returncode}")
        if result.stdout:
            print(f"   Output: {result.stdout[-500:]}")  # Last 500 chars
        if result.stderr:
            print(f"   Error: {result.stderr[-500:]}")  # Last 500 chars
# Out:
# 🧹 Running cleanup script...
#    Script: /home/pgx3874/pgx-analysis/2_create_cohort/cleanup_cohort_data.sh
#    Command: bash /home/pgx3874/pgx-analysis/2_create_cohort/cleanup_cohort_data.sh --yes
#    ⚠️  Auto-confirmation enabled (--yes flag)
# ==========================================
# Cohort Data Cleanup Script
# ==========================================
#
# This script will clear:
#   - Step 2: Cohort parquet files
#   - Step 3b: Feature importance outputs
#   - Step 4a: Model data
#   - Step 6: Trained models
#   - Checkpoints (optional)
#
# NOTE: Gold medical/pharmacy tables are preserved
#   (These are shared across workers and should not be deleted)
#
# WARNING: This will delete data!
#
# Auto-confirmation enabled (--yes flag). Proceeding with cleanup...
# ==========================================
# Cohort Data Cleanup Log
# Started: Tue Jan 20 07:24:45 UTC 2026
# ==========================================
#
#
# ==========================================
# Scanning existing data...
# ==========================================
# --- Scanning existing data ---
#
# --- Step 2: Cohort Data ---
# --- Step 2: Cohort Data ---
# [S3 MISSING] Step 2: ED_NON_OPIOID cohorts (S3 - new format)
#             Path: s3://pgxdatalake/gold/cohorts/cohort_name=ed_non_opioid/
# [S3 MISSING] Step 2: OPIOID_ED cohorts (S3 - new format)
#             Path: s3://pgxdatalake/gold/cohorts/cohort_name=opioid_ed/
# [S3 MISSING] Step 2: Legacy cohorts_F1120 (S3 - old format)
#             Path: s3://pgxdatalake/gold/cohorts_F1120/
# [S3 MISSING] Step 2: Legacy cohorts_model_data (S3 - old format)
#             Path: s3://pgxdatalake/gold/cohorts_model_data/
# [LOCAL MISSING] Step 2: ED_NON_OPIOID cohorts (local)
#                Path: /mnt/nvme/gold/cohorts/cohort_name=ed_non_opioid
# [LOCAL MISSING] Step 2: OPIOID_ED cohorts (local)
#                Path: /mnt/nvme/gold/cohorts/cohort_name=opioid_ed
#
# --- Step 3b: Feature Importance Outputs ---
# --- Step 3b: Feature Importance Outputs ---
# [LOCAL MISSING] Step 3b: ED_NON_OPIOID feature importance
#                Path: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/ed_non_opioid
# [LOCAL MISSING] Step 3b: OPIOID_ED feature importance
#                Path: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed
# [S3 MISSING] Step 3b: ED_NON_OPIOID BupaR outputs (S3)
#             Path: s3://pgxdatalake/gold/bupar/ed_non_opioid/
# [S3 MISSING] Step 3b: OPIOID_ED BupaR outputs (S3)
#             Path: s3://pgxdatalake/gold/bupar/opioid_ed/
# [S3 MISSING] Step 3b: ED_NON_OPIOID feature importance (S3)
#             Path: s3://pgxdatalake/gold/feature_importance/ed_non_opioid/
# [S3 MISSING] Step 3b: OPIOID_ED feature importance (S3)
#             Path: s3://pgxdatalake/gold/feature_importance/opioid_ed/
#
# --- Step 4a: Model Data ---
# --- Step 4a: Model Data ---
# [LOCAL MISSING] Step 4a: ED_NON_OPIOID model data (NVMe - old format)
#                Path: /mnt/nvme/4a_model_data/cohort_name=ed_non_opioid
# [LOCAL MISSING] Step 4a: OPIOID_ED model data (NVMe - old format)
#                Path: /mnt/nvme/4a_model_data/cohort_name=opioid_ed
# [LOCAL MISSING] Step 4a: POLYPHARMACY model data (NVMe - new format)
#                Path: /mnt/nvme/4a_model_data/cohorts/input_model_data/cohort_name=polypharmacy
# [LOCAL MISSING] Step 4a: OPIOID model data (NVMe - new format)
#                Path: /mnt/nvme/4a_model_data/cohorts/input_model_data/cohort_name=opioid
# [LOCAL MISSING] Step 4a: ED_NON_OPIOID model data (project - old format)
#                Path: /home/pgx3874/pgx-analysis/4a_model_data/cohort_name=ed_non_opioid
# [LOCAL MISSING] Step 4a: OPIOID_ED model data (project - old format)
#                Path: /home/pgx3874/pgx-analysis/4a_model_data/cohort_name=opioid_ed
# [LOCAL MISSING] Step 4a: POLYPHARMACY model data (project - new format)
#                Path: /home/pgx3874/pgx-analysis/4a_model_data/cohorts/input_model_data/cohort_name=polypharmacy
# [LOCAL MISSING] Step 4a: OPIOID model data (project - new format)
#                Path: /home/pgx3874/pgx-analysis/4a_model_data/cohorts/input_model_data/cohort_name=opioid
# [S3 MISSING] Step 4a: ED_NON_OPIOID model data (S3 - old format)
#             Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=ed_non_opioid/
# [S3 MISSING] Step 4a: OPIOID_ED model data (S3 - old format)
#             Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=opioid_ed/
# [S3 MISSING] Step 4a: POLYPHARMACY model data (S3 - new format)
#             Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=polypharmacy/
# [S3 MISSING] Step 4a: OPIOID model data (S3 - new format)
#             Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=opioid/
# [S3 MISSING] Step 4a: ED_NON_OPIOID model data (S3 - legacy)
#             Path: s3://pgxdatalake/gold/4a_model_data/cohort_name=ed_non_opioid/
# [S3 MISSING] Step 4a: OPIOID_ED model data (S3 - legacy)
#             Path: s3://pgxdatalake/gold/4a_model_data/cohort_name=opioid_ed/
#
# --- Step 6: Trained Models ---
# --- Step 6: Trained Models ---
# [LOCAL MISSING] Step 6: All trained models
#                Path: /home/pgx3874/pgx-analysis/6_final_model/models
# [S3 MISSING] Step 6: Trained models (S3)
#             Path: s3://pgxdatalake/gold/models/
#
# --- Checkpoints ---
# --- Checkpoints ---
# [S3 MISSING] Step 2: Cohort creation checkpoints
#             Path: s3://pgx-repository/pgx-pipeline-status/create_cohort/
# [S3 MISSING] Step 3b: Feature importance checkpoints
#             Path: s3://pgx-repository/pgx-pipeline-status/feature_importance_eda/
# [S3 MISSING] Step 4a: Model data checkpoints
#             Path: s3://pgx-repository/pgx-pipeline-status/model_data/
# [S3 MISSING] Step 6: Model training checkpoints
#             Path: s3://pgx-repository/pgx-pipeline-status/final_model/
#
# --- End of scan ---
#
#
# ==========================================
# Starting cleanup...
# ==========================================
# ==========================================
# Starting cleanup...
# ==========================================
#
#
# --- Step 2: Cohort Data ---
# [S3] Deleting: Step 2: ED_NON_OPIOID cohorts (S3 - new format)
# [S3 DELETE] Step 2: ED_NON_OPIOID cohorts (S3 - new format)
#            Path: s3://pgxdatalake/gold/cohorts/cohort_name=ed_non_opioid/
# [S3] Path not found (may already be deleted): Step 2: ED_NON_OPIOID cohorts (S3 - new format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 2: OPIOID_ED cohorts (S3 - new format)
# [S3 DELETE] Step 2: OPIOID_ED cohorts (S3 - new format)
#            Path: s3://pgxdatalake/gold/cohorts/cohort_name=opioid_ed/
# [S3] Path not found (may already be deleted): Step 2: OPIOID_ED cohorts (S3 - new format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 2: Legacy cohorts_F1120 (S3 - old format)
# [S3 DELETE] Step 2: Legacy cohorts_F1120 (S3 - old format)
#            Path: s3://pgxdatalake/gold/cohorts_F1120/
# [S3] Path not found (may already be deleted): Step 2: Legacy cohorts_F1120 (S3 - old format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 2: Legacy cohorts_model_data (S3 - old format)
# [S3 DELETE] Step 2: Legacy cohorts_model_data (S3 - old format)
#            Path: s3://pgxdatalake/gold/cohorts_model_data/
# [S3] Path not found (may already be deleted): Step 2: Legacy cohorts_model_data (S3 - old format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 2: ED_NON_OPIOID cohorts (local)
# [LOCAL DELETE] Step 2: ED_NON_OPIOID cohorts (local)
#               Path: /mnt/nvme/gold/cohorts/cohort_name=ed_non_opioid
# [LOCAL] Path not found (may already be deleted): Step 2: ED_NON_OPIOID cohorts (local)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 2: OPIOID_ED cohorts (local)
# [LOCAL DELETE] Step 2: OPIOID_ED cohorts (local)
#               Path: /mnt/nvme/gold/cohorts/cohort_name=opioid_ed
# [LOCAL] Path not found (may already be deleted): Step 2: OPIOID_ED cohorts (local)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
#
# --- Step 3b: Feature Importance Outputs ---
# [LOCAL] Deleting: Step 3b: ED_NON_OPIOID feature importance
# [LOCAL DELETE] Step 3b: ED_NON_OPIOID feature importance
#               Path: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/ed_non_opioid
# [LOCAL] Path not found (may already be deleted): Step 3b: ED_NON_OPIOID feature importance
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 3b: OPIOID_ED feature importance
# [LOCAL DELETE] Step 3b: OPIOID_ED feature importance
#               Path: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed
# [LOCAL] Path not found (may already be deleted): Step 3b: OPIOID_ED feature importance
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 3b: ED_NON_OPIOID BupaR outputs (S3)
# [S3 DELETE] Step 3b: ED_NON_OPIOID BupaR outputs (S3)
#            Path: s3://pgxdatalake/gold/bupar/ed_non_opioid/
# [S3] Path not found (may already be deleted): Step 3b: ED_NON_OPIOID BupaR outputs (S3)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 3b: OPIOID_ED BupaR outputs (S3)
# [S3 DELETE] Step 3b: OPIOID_ED BupaR outputs (S3)
#            Path: s3://pgxdatalake/gold/bupar/opioid_ed/
# [S3] Path not found (may already be deleted): Step 3b: OPIOID_ED BupaR outputs (S3)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 3b: ED_NON_OPIOID feature importance (S3)
# [S3 DELETE] Step 3b: ED_NON_OPIOID feature importance (S3)
#            Path: s3://pgxdatalake/gold/feature_importance/ed_non_opioid/
# [S3] Path not found (may already be deleted): Step 3b: ED_NON_OPIOID feature importance (S3)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 3b: OPIOID_ED feature importance (S3)
# [S3 DELETE] Step 3b: OPIOID_ED feature importance (S3)
#            Path: s3://pgxdatalake/gold/feature_importance/opioid_ed/
# [S3] Path not found (may already be deleted): Step 3b: OPIOID_ED feature importance (S3)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
#
# --- Step 4a: Model Data ---
# [LOCAL] Deleting: Step 4a: ED_NON_OPIOID model data (NVMe - old format)
# [LOCAL DELETE] Step 4a: ED_NON_OPIOID model data (NVMe - old format)
#               Path: /mnt/nvme/4a_model_data/cohort_name=ed_non_opioid
# [LOCAL] Path not found (may already be deleted): Step 4a: ED_NON_OPIOID model data (NVMe - old format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: OPIOID_ED model data (NVMe - old format)
# [LOCAL DELETE] Step 4a: OPIOID_ED model data (NVMe - old format)
#               Path: /mnt/nvme/4a_model_data/cohort_name=opioid_ed
# [LOCAL] Path not found (may already be deleted): Step 4a: OPIOID_ED model data (NVMe - old format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: POLYPHARMACY model data (NVMe - new format)
# [LOCAL DELETE] Step 4a: POLYPHARMACY model data (NVMe - new format)
#               Path: /mnt/nvme/4a_model_data/cohorts/input_model_data/cohort_name=polypharmacy
# [LOCAL] Path not found (may already be deleted): Step 4a: POLYPHARMACY model data (NVMe - new format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: OPIOID model data (NVMe - new format)
# [LOCAL DELETE] Step 4a: OPIOID model data (NVMe - new format)
#               Path: /mnt/nvme/4a_model_data/cohorts/input_model_data/cohort_name=opioid
# [LOCAL] Path not found (may already be deleted): Step 4a: OPIOID model data (NVMe - new format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: ED_NON_OPIOID model data (project - old format)
# [LOCAL DELETE] Step 4a: ED_NON_OPIOID model data (project - old format)
#               Path: /home/pgx3874/pgx-analysis/4a_model_data/cohort_name=ed_non_opioid
# [LOCAL] Path not found (may already be deleted): Step 4a: ED_NON_OPIOID model data (project - old format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: OPIOID_ED model data (project - old format)
# [LOCAL DELETE] Step 4a: OPIOID_ED model data (project - old format)
#               Path: /home/pgx3874/pgx-analysis/4a_model_data/cohort_name=opioid_ed
# [LOCAL] Path not found (may already be deleted): Step 4a: OPIOID_ED model data (project - old format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: POLYPHARMACY model data (project - new format)
# [LOCAL DELETE] Step 4a: POLYPHARMACY model data (project - new format)
#               Path: /home/pgx3874/pgx-analysis/4a_model_data/cohorts/input_model_data/cohort_name=polypharmacy
# [LOCAL] Path not found (may already be deleted): Step 4a: POLYPHARMACY model data (project - new format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [LOCAL] Deleting: Step 4a: OPIOID model data (project - new format)
# [LOCAL DELETE] Step 4a: OPIOID model data (project - new format)
#               Path: /home/pgx3874/pgx-analysis/4a_model_data/cohorts/input_model_data/cohort_name=opioid
# [LOCAL] Path not found (may already be deleted): Step 4a: OPIOID model data (project - new format)
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: ED_NON_OPIOID model data (S3 - old format)
# [S3 DELETE] Step 4a: ED_NON_OPIOID model data (S3 - old format)
#            Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=ed_non_opioid/
# [S3] Path not found (may already be deleted): Step 4a: ED_NON_OPIOID model data (S3 - old format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: OPIOID_ED model data (S3 - old format)
# [S3 DELETE] Step 4a: OPIOID_ED model data (S3 - old format)
#            Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=opioid_ed/
# [S3] Path not found (may already be deleted): Step 4a: OPIOID_ED model data (S3 - old format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: POLYPHARMACY model data (S3 - new format)
# [S3 DELETE] Step 4a: POLYPHARMACY model data (S3 - new format)
#            Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=polypharmacy/
# [S3] Path not found (may already be deleted): Step 4a: POLYPHARMACY model data (S3 - new format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: OPIOID model data (S3 - new format)
# [S3 DELETE] Step 4a: OPIOID model data (S3 - new format)
#            Path: s3://pgxdatalake/gold/cohorts/input_model_data/cohort_name=opioid/
# [S3] Path not found (may already be deleted): Step 4a: OPIOID model data (S3 - new format)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: ED_NON_OPIOID model data (S3 - legacy)
# [S3 DELETE] Step 4a: ED_NON_OPIOID model data (S3 - legacy)
#            Path: s3://pgxdatalake/gold/4a_model_data/cohort_name=ed_non_opioid/
# [S3] Path not found (may already be deleted): Step 4a: ED_NON_OPIOID model data (S3 - legacy)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: OPIOID_ED model data (S3 - legacy)
# [S3 DELETE] Step 4a: OPIOID_ED model data (S3 - legacy)
#            Path: s3://pgxdatalake/gold/4a_model_data/cohort_name=opioid_ed/
# [S3] Path not found (may already be deleted): Step 4a: OPIOID_ED model data (S3 - legacy)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
#
# --- Step 6: Trained Models ---
# [LOCAL] Deleting: Step 6: All trained models
# [LOCAL DELETE] Step 6: All trained models
#               Path: /home/pgx3874/pgx-analysis/6_final_model/models
# [LOCAL] Path not found (may already be deleted): Step 6: All trained models
#               Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 6: Trained models (S3)
# [S3 DELETE] Step 6: Trained models (S3)
#            Path: s3://pgxdatalake/gold/models/
# [S3] Path not found (may already be deleted): Step 6: Trained models (S3)
#            Status: NOT FOUND (already deleted or doesn't exist)
#
#
# --- Checkpoints ---
# [S3] Deleting: Step 2: Cohort creation checkpoints
# [S3 DELETE] Step 2: Cohort creation checkpoints
#            Path: s3://pgx-repository/pgx-pipeline-status/create_cohort/
# [S3] Path not found (may already be deleted): Step 2: Cohort creation checkpoints
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 3b: Feature importance checkpoints
# [S3 DELETE] Step 3b: Feature importance checkpoints
#            Path: s3://pgx-repository/pgx-pipeline-status/feature_importance_eda/
# [S3] Path not found (may already be deleted): Step 3b: Feature importance checkpoints
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 4a: Model data checkpoints
# [S3 DELETE] Step 4a: Model data checkpoints
#            Path: s3://pgx-repository/pgx-pipeline-status/model_data/
# [S3] Path not found (may already be deleted): Step 4a: Model data checkpoints
#            Status: NOT FOUND (already deleted or doesn't exist)
#
# [S3] Deleting: Step 6: Model training checkpoints
# [S3 DELETE] Step 6: Model training checkpoints
#            Path: s3://pgx-repository/pgx-pipeline-status/final_model/
# [S3] Path not found (may already be deleted): Step 6: Model training checkpoints
#            Status: NOT FOUND (already deleted or doesn't exist)
#
#
# ==========================================
# Cleanup completed: Tue Jan 20 07:25:06 UTC 2026
# ==========================================
# Deleted 0 items
#
# Log file saved to: /home/pgx3874/pgx-analysis/cleanup_cohort_data_20260120_072445.log
#
#
# ==========================================
# Cleanup completed!
# ==========================================
# Deleted 0 items
#
# Log file saved to: /home/pgx3874/pgx-analysis/cleanup_cohort_data_20260120_072445.log
#
# Next steps:
#   1. Rerun Step 2 to create cohorts with new time-windowed logic:
#      python 2_create_cohort/0_create_cohort.py --age-band <age_band> --event-year <year> --cohort ed_non_opioid --time-window-days 14
#
#   2. Rerun Step 3b for feature importance:
#      python 3b_feature_importance_eda/run_feature_importance_eda.py --cohort ed_non_opioid --age-band <age_band>
#
#   3. Rerun Step 4a to create model data:
#      python 4a_model_data/create_model_data.py --cohort ed_non_opioid --age-band <age_band>
#
#   4. Rerun Step 6 to train models:
#      python 6_final_model/train_models.py --cohort ed_non_opioid --age-band <age_band>
#
#
# ✅ Cleanup completed successfully

# %% [markdown]
# ## C. Create Cohorts
#
# This section creates cohorts with the new time-windowed HCG event logic.
#
# ### Cohort Types:
#
# 1. **OPIOID_ED** (`opioid_ed`): Uses F11.20 as target event (no time windowing)
# 2. **POLYPHARMACY** (`non_opioid_ed`): Uses time-windowed HCG events as target
#
# ### Time Windows:
#
# For the polypharmacy cohort, multiple time windows are created:
# - 7 days
# - 14 days (default)
# - 21 days
# - 30 days
# - 45 days
#
# The main `is_target_case` column uses the specified `TIME_WINDOW_DAYS`.
# Additional columns (`is_target_case_7d`, `is_target_case_14d`, etc.) are created for multiclass analysis.

# %%
# %%bash
# set -euo pipefail
#
# export PGX_DUCKDB_THREADS=16
# export PGX_DUCKDB_MEMORY_LIMIT=256GB
# export PGX_TOTAL_WORKERS=2
#
# cd /home/pgx3874/pgx-analysis
#
# # Launch ed_non_opioid
# nohup /home/pgx3874/jupyter-env/bin/python3.11 2_create_cohort/run_series_ed_non_opioid.py \
#   --skip-existing \
#   --concurrent-workers 1 \
#   > logs/ed_non_opioid_run.log 2>&1 &
# echo "ed_non_opioid PID: $!"
# Out:
# bash: line 7: cd: /home/ec2-user/pgx-analysis: Permission denied
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'set -euo pipefail\n\nexport PGX_DUCKDB_THREADS=16\nexport PGX_DUCKDB_MEMORY_LIMIT=256GB\nexport PGX_TOTAL_WORKERS=2\n\ncd /home/ec2-user/pgx-analysis\n\n# Launch ed_non_opioid\nnohup /home/pgx3874/jupyter-env/bin/python3.11 2_create_cohort/run_series_ed_non_opioid.py \\\n  --skip-existing \\\n  --concurrent-workers 1 \\\n  > logs/ed_non_opioid_run.log 2>&1 &\necho "ed_non_opioid PID: $!"\n')
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2547, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2545 with self.builtin_trap:
#    2546     args = (magic_arg_s, cell)
# -> 2547     result = fn(*args, **kwargs)
#    2549 # The code below prevents the output from being displayed
#    2550 # when using magics with decorator @output_can_be_silenced
#    2551 # when the last Python token in the expression is a ';'.
#    2552 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     157 else:
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/jupyter-env/lib/python3.11/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'set -euo pipefail\n\nexport PGX_DUCKDB_THREADS=16\nexport PGX_DUCKDB_MEMORY_LIMIT=256GB\nexport PGX_TOTAL_WORKERS=2\n\ncd /home/ec2-user/pgx-analysis\n\n# Launch ed_non_opioid\nnohup /home/pgx3874/jupyter-env/bin/python3.11 2_create_cohort/run_series_ed_non_opioid.py \\\n  --skip-existing \\\n  --concurrent-workers 1 \\\n  > logs/ed_non_opioid_run.log 2>&1 &\necho "ed_non_opioid PID: $!"\n'' returned non-zero exit status 1.

# %%
# %%bash
# set -euo pipefail
#
# export PGX_DUCKDB_THREADS=12
# export PGX_DUCKDB_MEMORY_LIMIT=192GB
# export PGX_TOTAL_WORKERS=2
#
# cd /home/pgx3874/pgx-analysis
#
# # Cell 3: Launch opioid_ed
# nohup /home/pgx3874/jupyter-env/bin/python3.11 2_create_cohort/run_series_opioid_ed.py \
#   --skip-existing \
#   --concurrent-workers 1 \
#   > logs/opioid_ed_run.log 2>&1 &
# echo "opioid_ed PID: $!"

# %% [markdown]
# ## D. Verify Cohort Creation
#
# This section verifies that cohorts were created successfully by checking S3 and local paths.

# %%
# Verify cohorts exist in S3
s3_client = boto3.client('s3')

print("📊 Verifying cohorts in S3...")
print("=" * 60)

cohort_mapping = {
    "opioid_ed": "opioid_ed",
    "non_opioid_ed": "ed_non_opioid"
}

all_found = True
for cohort in COHORTS:
    s3_cohort_name = cohort_mapping.get(cohort, cohort)
    
    for age_band in AGE_BANDS.get(cohort, []):
        for event_year in EVENT_YEARS:
            s3_key = f"gold/cohorts/cohort_name={s3_cohort_name}/age_band={age_band}/event_year={event_year}/cohort.parquet"
            
            try:
                s3_client.head_object(Bucket=S3_BUCKET, Key=s3_key)
                # Get file size
                response = s3_client.head_object(Bucket=S3_BUCKET, Key=s3_key)
                size_mb = response['ContentLength'] / (1024 * 1024)
                print(f"✅ {cohort}/{age_band}/{event_year}: {size_mb:.2f} MB")
            except s3_client.exceptions.ClientError as e:
                if e.response['Error']['Code'] == '404':
                    print(f"❌ {cohort}/{age_band}/{event_year}: NOT FOUND")
                    all_found = False
                else:
                    print(f"⚠️  {cohort}/{age_band}/{event_year}: ERROR - {e}")
                    all_found = False

print("=" * 60)
if all_found:
    print("✅ All cohorts verified in S3")
else:
    print("❌ Some cohorts are missing in S3")

# %%
# Verify multiclass target columns exist for polypharmacy cohort
import duckdb

print("📊 Verifying multiclass target columns for polypharmacy cohort...")
print("=" * 60)

# Connect to DuckDB and enable S3
con = duckdb.connect()
con.execute("INSTALL httpfs; LOAD httpfs;")
con.execute("INSTALL aws; LOAD aws;")
con.execute("CALL load_aws_credentials();")

# Check one polypharmacy cohort file
test_cohort = "non_opioid_ed"
test_age_band = AGE_BANDS[test_cohort][0]  # First age band
test_year = EVENT_YEARS[0]  # First year

s3_path = f"s3://{S3_BUCKET}/gold/cohorts/cohort_name=ed_non_opioid/age_band={test_age_band}/event_year={test_year}/cohort.parquet"

try:
    # Get schema
    schema_query = f"DESCRIBE SELECT * FROM read_parquet('{s3_path}') LIMIT 0"
    schema = con.execute(schema_query).fetchdf()
    
    print(f"\nColumns in {test_cohort}/{test_age_band}/{test_year}:")
    
    # Check for multiclass columns
    expected_columns = [
        'is_target_case',
        'is_target_case_7d',
        'is_target_case_14d',
        'is_target_case_21d',
        'is_target_case_30d',
        'is_target_case_45d'
    ]
    
    found_columns = []
    missing_columns = []
    
    for col in expected_columns:
        if col in schema['column_name'].values:
            found_columns.append(col)
            print(f"   ✅ {col}")
        else:
            missing_columns.append(col)
            print(f"   ❌ {col} (missing)")
    
    if len(missing_columns) == 0:
        print("\n✅ All multiclass target columns found")
    else:
        print(f"\n❌ Missing columns: {missing_columns}")
        
except Exception as e:
    print(f"❌ Error checking schema: {e}")

con.close()

# %% [markdown]
# ## Next Steps
#
# After successfully creating cohorts, proceed to:
#
# 1. **Step 3b: Feature Importance EDA**
#    - Run BupaR post-target analysis
#    - Filter post-target leakage features
#    - Generate refined feature importance files
#
# 2. **Step 4a: Model Data Creation**
#    - Create `model_events.parquet` with cases and controls
#    - Uses refined features from Step 3b
#
# 3. **Step 4b: Event Filtering**
#    - Filter administrative codes
#    - Remove post-event leakage
#
# 4. **Step 5: PGx Feature Engineering**
#    - Add PGx drug counts
#    - Add drug counts
#
# 5. **Step 6: Final Model Training**
#    - Train CatBoost, XGBoost, and XGBoost RF models
#    - Select best model by recall/AUC-PR
#
# See `WORKFLOW_EXECUTION_TODO.md` for detailed instructions.
