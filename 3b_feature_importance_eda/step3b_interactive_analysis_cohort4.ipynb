# %% [markdown]
# ## Navigation
#
# - **Section A**: Configuration and Setup
# - **Section B**: BupaR Post-Target Analysis (Leakage Detection)
# - **Section C**: Interactive Code Review and Filtering
# - **Section D**: Generate Final Refined Feature Importances

# %% [markdown]
# ## A. Configuration and Setup

# %%
import sys
import os
from pathlib import Path
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image, HTML
import warnings
warnings.filterwarnings('ignore')

# Set project root
PROJECT_ROOT = Path('/home/pgx3874/pgx-analysis')  # Update for your EC2 path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Jupyter environment Python path (update if different)
PYTHON_BIN = Path('/home/pgx3874/jupyter-env/bin/python3.11')  # Full path to Jupyter Python
if not PYTHON_BIN.exists():
    # Fallback to sys.executable if custom path doesn't exist
    PYTHON_BIN = Path(sys.executable)
    print(f"⚠️  Custom Python path not found, using: {PYTHON_BIN}")

# Rscript path for BupaR analysis (update if different)
# The Python script will try to find Rscript automatically, but you can specify it here
# Based on EC2 setup: R is at /usr/local/bin/R, so Rscript is likely at /usr/local/bin/Rscript
RSCRIPT_BIN = Path('/usr/local/bin/Rscript')  # EC2 default location
if not RSCRIPT_BIN.exists():
    # Fallback to None for auto-detection if path doesn't exist
    RSCRIPT_BIN = None
    print(f"⚠️  Rscript not found at {Path('/usr/local/bin/Rscript')}, will use auto-detection")

# Import project utilities
from py_helpers.constants import age_band_to_fname

# Configuration
COHORT = "opioid_ed"  # OPIOID_ED cohort (pre-configured)
AGE_BAND = "55-64"    # Change as needed for different age bands
AGE_BAND_FNAME = age_band_to_fname(AGE_BAND)

# Output directories
OUTPUT_DIR = PROJECT_ROOT / "3b_feature_importance_eda" / "outputs" / COHORT / AGE_BAND_FNAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PLOTS_DIR = OUTPUT_DIR / "plots"
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

print(f"✅ Configuration loaded")
print(f"   Cohort: {COHORT}")
print(f"   Age Band: {AGE_BAND} ({AGE_BAND_FNAME})")
print(f"   Python Binary: {PYTHON_BIN}")
if RSCRIPT_BIN:
    print(f"   Rscript Binary: {RSCRIPT_BIN}")
else:
    print(f"   Rscript Binary: Auto-detect (will be found by script)")
print(f"   Output Directory: {OUTPUT_DIR}")
# Out:
# ✅ Configuration loaded
#    Cohort: opioid_ed
#    Age Band: 55-64 (55_64)
#    Python Binary: /home/pgx3874/jupyter-env/bin/python3.11
#    Rscript Binary: /usr/local/bin/Rscript
#    Output Directory: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64

# %% [markdown]
# ### 1. Load Aggregated Feature Importances from Step 3

# %%
# Load aggregated feature importance from Step 3
possible_paths = [
    PROJECT_ROOT / "3_feature_importance" / "outputs" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
    PROJECT_ROOT / "3_feature_importance" / "from_s3" / "by_cohort" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
]

aggregated_fi = None
for path in possible_paths:
    if path.exists():
        aggregated_fi = pd.read_csv(path)
        print(f"✅ Loaded aggregated feature importance from: {path}")
        print(f"   Total features: {len(aggregated_fi):,}")
        break

if aggregated_fi is None:
    print(f"❌ Could not find aggregated feature importance file")
    print(f"   Checked paths:")
    for path in possible_paths:
        print(f"     - {path}")
else:
    # Display summary
    print(f"\n📊 Feature Importance Summary:")
    print(f"   Columns: {list(aggregated_fi.columns)}")
    print(f"\n   Top 10 features:")
    display(aggregated_fi.head(10))
# Out:
# ✅ Loaded aggregated feature importance from: /home/pgx3874/pgx-analysis/3_feature_importance/outputs/opioid_ed/55-64/opioid_ed_55_64_aggregated_feature_importance.csv
#    Total features: 3,882
#
# 📊 Feature Importance Summary:
#    Columns: ['feature', 'importance_normalized', 'importance_scaled', 'n_models']
#
#    Top 10 features:
#                           feature  importance_normalized  importance_scaled  \
# 0                      item_H0020               1.000000           0.768892
# 1                      item_G0483               0.916374           0.704593
# 2                      item_80307               0.813450           0.625455
# 3                   item_SUBOXONE               0.687962           0.528969
# 4                      item_G0480               0.579259           0.445388
# 5                      item_80305               0.481336           0.370096
# 6                      item_G0444               0.355508           0.273347
# 7                      item_S0109               0.319547           0.245697
# 8  item_BUPRENORPHINE HCL/NALOXON               0.303856           0.233632
# 9                      item_G0481               0.230071           0.176900
#
#    n_models
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# 5         3
# 6         3
# 7         3
# 8         3
# 9         3

# %% [markdown]
# ## C. BupaR Post-Target Analysis (Leakage Detection)
#
# BupaR analysis identifies features that appear primarily after the target event (potential leakage).

# %% [markdown]
# ### 1. Verify Rscript is Available
#
# **Note:** BupaR analysis uses R scripts, so Rscript must be installed and available in PATH. The Python script will automatically find Rscript, but you can verify it's available here.

# %%
# Verify Rscript is available
import shutil
import subprocess

# Check configured path first
if RSCRIPT_BIN and RSCRIPT_BIN.exists():
    print(f"✅ Rscript found at configured path: {RSCRIPT_BIN}")
    rscript_path = str(RSCRIPT_BIN)
else:
    # Try to find in PATH
    rscript_path = shutil.which("Rscript")
    if rscript_path:
        print(f"✅ Rscript found in PATH: {rscript_path}")
    else:
        # Try common EC2 locations
        common_paths = [
            Path('/usr/local/bin/Rscript'),  # EC2 default
            Path('/usr/bin/Rscript'),
        ]
        found = False
        for path in common_paths:
            if path.exists():
                print(f"✅ Rscript found at: {path}")
                rscript_path = str(path)
                found = True
                break
        if not found:
            print(f"⚠️  Rscript not found")
            print(f"   The Python script will try to find it automatically")
            rscript_path = None

# Check version if found
if rscript_path:
    try:
        result = subprocess.run([rscript_path, "--version"], capture_output=True, text=True, timeout=5)
        if result.returncode == 0:
            version_line = result.stdout.strip().split('\n')[0] if result.stdout else "Unknown"
            print(f"   Version: {version_line}")
    except Exception as e:
        print(f"   Could not check version: {e}")

print("\n" + "="*80)
# Out:
# ✅ Rscript found at configured path: /usr/local/bin/Rscript
#    Version: Rscript (R) version 4.4.3 (2025-02-28)
#
# ================================================================================

# %% [markdown]
# ### 2. Run BupaR Post-Target Analysis
#
# **Note:** This Python script calls R scripts (`create_bupar_outputs_*.R`) using Rscript. The script automatically finds Rscript, so no manual configuration is needed.

# %%
import subprocess
from datetime import datetime

print("🚀 Running BupaR Post-Target Analysis...")
print(f"Started at: {datetime.now()}")
print(f"Note: This will call R scripts using Rscript")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "run_bupar_post_target_analysis.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ BupaR analysis completed successfully")
else:
    print(f"\n❌ BupaR analysis failed with return code {result.returncode}")
    if "Rscript not found" in result.stderr or "Rscript not found" in result.stdout:
        print("\n💡 Tip: Make sure R is installed and Rscript is in your PATH")
        print("   Or set RSCRIPT_BIN in the configuration cell above")
# Out:
# 🚀 Running BupaR Post-Target Analysis...
# Started at: 2026-01-18 02:34:26.029851
# Note: This will call R scripts using Rscript
#
# ================================================================================
# BupaR Analysis: opioid_ed / 55-64
# ================================================================================
# [INFO] Using Rscript: /usr/local/bin/Rscript
# [INFO] Running: /usr/local/bin/Rscript /home/pgx3874/pgx-analysis/3b_feature_importance_eda/1_bupaR/create_bupar_outputs_opioid_ed.R 55-64
# [INFO] Working directory: /home/pgx3874/pgx-analysis
# [OK] R script completed successfully
# R Output:
# === bupaR Analysis: Cohort 1 (OPIOID_ED) ===
#   Age band:       55-64
#   Control cohort: non_opioid_ed
#
# Project root:         /home/pgx3874/pgx-analysis
# Model data path:      /mnt/nvme/4a_model_data/cohort_name=opioid_ed/age_band=55-64/model_events.parquet
# Note: Using all codes from model_data (FP-Growth filtering removed)
#
# Loaded 6221611 events for opioid_ed age_band=55-64 across years 2016,2017,2018
# Target=1 rows: 1197144
# Target eventlog created.
# # Log of 1818475 events consisting of:
# 4209 cases
# 1818475 instances of 11625 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,818,475 × 7
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1002697828 DRUG:GABAPE… 2017-01-03 00:00:00                    1 complete
#  2 1002697828 DRUG:VOLTAR… 2017-01-04 00:00:00                    2 complete
#  3 1002697828 DRUG:COLCRYS 2017-01-04 00:00:00                    3 complete
#  4 1002697828 DRUG:ATORVA… 2017-01-14 00:00:00                    4 complete
#  5 1002697828 DRUG:ESOMEP… 2017-01-18 00:00:00                    5 complete
#  6 1002697828 DRUG:PULMIC… 2017-01-20 00:00:00                    6 complete
#  7 1002697828 DRUG:AZITHR… 2017-01-20 00:00:00                    7 complete
#  8 1002697828 DRUG:HYDROC… 2017-01-20 00:00:00                    8 complete
#  9 1002697828 DRUG:COLCRYS 2017-01-28 00:00:00                    9 complete
# 10 1002697828 DRUG:CLONAZ… 2017-01-30 00:00:00                   10 complete
# # ℹ 1,818,465 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
# Combined TARGET + CONTROL sankey_eventlog created.
# # Log of 1818475 events consisting of:
# 4209 cases
# 1818475 instances of 11625 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,818,475 × 8
#    case_id  activity timestamp           group activity_instance_id lifecycle_id
#    <chr>    <chr>    <dttm>              <chr>                <int> <chr>
#  1 1002697… DRUG:GA… 2017-01-03 00:00:00 targ…                    1 complete
#  2 1002697… DRUG:VO… 2017-01-04 00:00:00 targ…                    2 complete
#  3 1002697… DRUG:CO… 2017-01-04 00:00:00 targ…                    3 complete
#  4 1002697… DRUG:AT… 2017-01-14 00:00:00 targ…                    4 complete
#  5 1002697… DRUG:ES… 2017-01-18 00:00:00 targ…                    5 complete
#  6 1002697… DRUG:PU… 2017-01-20 00:00:00 targ…                    6 complete
#  7 1002697… DRUG:AZ… 2017-01-20 00:00:00 targ…                    7 complete
#  8 1002697… DRUG:HY… 2017-01-20 00:00:00 targ…                    8 complete
#  9 1002697… DRUG:CO… 2017-01-28 00:00:00 targ…                    9 complete
# 10 1002697… DRUG:CL… 2017-01-30 00:00:00 targ…                   10 complete
# # ℹ 1,818,465 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
#
# --- Pre-F1120 (before first ICD:F1120) analysis ---
# Pre-F1120 eventlog summary:
# # Log of 521471 events consisting of:
# 3963 cases
# 521471 instances of 7958 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-28
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 521,471 × 11
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1000000863 DRUG:RANITI… 2016-01-04 00:00:00                    1 complete
#  2 1000000863 DRUG:RANITI… 2016-01-04 00:00:00                    2 complete
#  3 1000000863 DRUG:BUPREN… 2016-01-05 00:00:00                    3 complete
#  4 1000000863 DRUG:CLONAZ… 2016-01-05 00:00:00                    4 complete
#  5 1000000863 DRUG:BUPREN… 2016-01-05 00:00:00                    5 complete
#  6 1000000863 DRUG:CLONAZ… 2016-01-05 00:00:00                    6 complete
#  7 1000001678 ICD:S32019A  2016-03-06 00:00:00                    7 complete
#  8 1000001678 CPT:99053    2016-03-06 00:00:00                    8 complete
#  9 1000001678 ICD:S32019A  2016-03-06 00:00:00                    9 complete
# 10 1000001678 CPT:99285    2016-03-06 00:00:00                   10 complete
# # ℹ 521,461 more rows
# # ℹ 6 more variables: resource_id <chr>, .order <int>, event_index <int>,
# #   is_target_icd <lgl>, has_target <lgl>, first_target_index <int>
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_traces_bupar.csv"
# Completed 1.0 MiB/6.8 MiB (67.0 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/6.8 MiB (41.1 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/6.8 MiB (59.9 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/6.8 MiB (77.8 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/6.8 MiB (95.3 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/6.8 MiB (112.2 MiB/s) with 1 file(s) remaining
# Completed 6.8 MiB/6.8 MiB (124.4 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_traces_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_traces_rare_bupar.csv"
# Completed 1.0 MiB/6.8 MiB (82.5 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/6.8 MiB (38.8 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/6.8 MiB (56.5 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/6.8 MiB (71.9 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/6.8 MiB (84.9 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/6.8 MiB (99.9 MiB/s) with 1 file(s) remaining
# Completed 6.8 MiB/6.8 MiB (95.7 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_traces_rare_bupar.csv
# Saved 3906 rare pre-F1120 sequences (frequency <= 1)
# Sample pre-F1120 drug-only sequences:
# # A tibble: 6 × 2
#   case_id    drug_sequence
#   <chr>      <list>
# 1 1000000863 <chr [6]>
# 2 1000004067 <chr [1]>
# 3 1000004405 <chr [179]>
# 4 1000015504 <chr [66]>
# 5 1000018141 <chr [91]>
# 6 1000018593 <chr [100]>
# Created pre-F1120 activity frequency and Gantt timeline plots (overall + by code type).
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_patient_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_patient_features_bupar.csv"
# Completed 99.1 KiB/99.1 KiB (1.2 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_pre_f1120_patient_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_pre_f1120_patient_features_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_time_to_f1120_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_time_to_f1120_features_bupar.csv"
# Completed 343.0 KiB/343.0 KiB (21.0 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_time_to_f1120_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_time_to_f1120_features_bupar.csv
#
# --- Post-F1120 (after first ICD:F1120) analysis ---
# Post-F1120 eventlog summary:
# # Log of 1275891 events consisting of:
# 4156 cases
# 1275891 instances of 9980 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,275,891 × 11
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1000000863 CPT:G0479    2016-01-05 00:00:00                    1 complete
#  2 1000000863 DRUG:TAMSUL… 2016-01-11 00:00:00                    2 complete
#  3 1000000863 DRUG:TAMSUL… 2016-01-11 00:00:00                    3 complete
#  4 1000000863 DRUG:METFOR… 2016-01-18 00:00:00                    4 complete
#  5 1000000863 DRUG:METFOR… 2016-01-18 00:00:00                    5 complete
#  6 1000000863 DRUG:CLONAZ… 2016-02-02 00:00:00                    6 complete
#  7 1000000863 DRUG:BUPREN… 2016-02-02 00:00:00                    7 complete
#  8 1000000863 DRUG:CLONAZ… 2016-02-02 00:00:00                    8 complete
#  9 1000000863 DRUG:BUPREN… 2016-02-02 00:00:00                    9 complete
# 10 1000000863 DRUG:RANITI… 2016-02-08 00:00:00                   10 complete
# # ℹ 1,275,881 more rows
# # ℹ 6 more variables: resource_id <chr>, .order <int>, event_index <int>,
# #   is_target_icd <lgl>, has_target <lgl>, first_target_index <int>
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_traces_bupar.csv"
# Completed 1.0 MiB/16.4 MiB (14.9 MiB/s) with 1 file(s) remaining
# Completed 1.4 MiB/16.4 MiB (18.6 MiB/s) with 1 file(s) remaining
# Completed 2.4 MiB/16.4 MiB (31.3 MiB/s) with 1 file(s) remaining
# Completed 3.4 MiB/16.4 MiB (39.2 MiB/s) with 1 file(s) remaining
# Completed 4.4 MiB/16.4 MiB (48.5 MiB/s) with 1 file(s) remaining
# Completed 5.4 MiB/16.4 MiB (55.9 MiB/s) with 1 file(s) remaining
# Completed 6.4 MiB/16.4 MiB (64.2 MiB/s) with 1 file(s) remaining
# Completed 7.4 MiB/16.4 MiB (72.0 MiB/s) with 1 file(s) remaining
# Completed 8.4 MiB/16.4 MiB (79.4 MiB/s) with 1 file(s) remaining
# Completed 9.4 MiB/16.4 MiB (87.3 MiB/s) with 1 file(s) remaining
# Completed 10.4 MiB/16.4 MiB (86.1 MiB/s) with 1 file(s) remaining
# Completed 11.4 MiB/16.4 MiB (93.2 MiB/s) with 1 file(s) remaining
# Completed 12.4 MiB/16.4 MiB (98.9 MiB/s) with 1 file(s) remaining
# Completed 13.4 MiB/16.4 MiB (105.4 MiB/s) with 1 file(s) remaining
# Completed 14.4 MiB/16.4 MiB (111.4 MiB/s) with 1 file(s) remaining
# Completed 15.4 MiB/16.4 MiB (118.3 MiB/s) with 1 file(s) remaining
# Completed 16.4 MiB/16.4 MiB (124.5 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_traces_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_traces_rare_bupar.csv"
# Completed 1.0 MiB/16.4 MiB (15.9 MiB/s) with 1 file(s) remaining
# Completed 1.4 MiB/16.4 MiB (19.4 MiB/s) with 1 file(s) remaining
# Completed 2.4 MiB/16.4 MiB (32.7 MiB/s) with 1 file(s) remaining
# Completed 3.4 MiB/16.4 MiB (41.5 MiB/s) with 1 file(s) remaining
# Completed 4.4 MiB/16.4 MiB (52.4 MiB/s) with 1 file(s) remaining
# Completed 5.4 MiB/16.4 MiB (63.0 MiB/s) with 1 file(s) remaining
# Completed 6.4 MiB/16.4 MiB (73.1 MiB/s) with 1 file(s) remaining
# Completed 7.4 MiB/16.4 MiB (82.5 MiB/s) with 1 file(s) remaining
# Completed 8.4 MiB/16.4 MiB (91.5 MiB/s) with 1 file(s) remaining
# Completed 9.4 MiB/16.4 MiB (99.8 MiB/s) with 1 file(s) remaining
# Completed 10.4 MiB/16.4 MiB (86.4 MiB/s) with 1 file(s) remaining
# Completed 11.4 MiB/16.4 MiB (91.6 MiB/s) with 1 file(s) remaining
# Completed 12.4 MiB/16.4 MiB (97.9 MiB/s) with 1 file(s) remaining
# Completed 13.4 MiB/16.4 MiB (103.3 MiB/s) with 1 file(s) remaining
# Completed 14.4 MiB/16.4 MiB (108.5 MiB/s) with 1 file(s) remaining
# Completed 15.4 MiB/16.4 MiB (113.3 MiB/s) with 1 file(s) remaining
# Completed 16.4 MiB/16.4 MiB (117.7 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_traces_rare_bupar.csv
# Saved 4130 rare post-F1120 sequences (frequency <= 1)
# Created post-F1120 activity frequency and Gantt timeline plots (overall + by code type).
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_patient_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_patient_features_bupar.csv"
# Completed 111.2 KiB/111.2 KiB (1.6 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_post_f1120_patient_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_post_f1120_patient_features_bupar.csv
#
# --- Target-only global process mining ---
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_traces_bupar.csv"
# Completed 1.0 MiB/23.3 MiB (13.8 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/23.3 MiB (24.9 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/23.3 MiB (36.5 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/23.3 MiB (43.9 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/23.3 MiB (54.0 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/23.3 MiB (64.2 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/23.3 MiB (74.1 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/23.3 MiB (83.9 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/23.3 MiB (93.6 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/23.3 MiB (103.1 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/23.3 MiB (90.8 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/23.3 MiB (97.8 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/23.3 MiB (104.9 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/23.3 MiB (112.0 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/23.3 MiB (119.2 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/23.3 MiB (126.4 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/23.3 MiB (133.6 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/23.3 MiB (140.6 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/23.3 MiB (148.3 MiB/s) with 1 file(s) remaining
# Completed 20.0 MiB/23.3 MiB (154.5 MiB/s) with 1 file(s) remaining
# Completed 21.0 MiB/23.3 MiB (161.0 MiB/s) with 1 file(s) remaining
# Completed 22.0 MiB/23.3 MiB (167.6 MiB/s) with 1 file(s) remaining
# Completed 23.0 MiB/23.3 MiB (174.1 MiB/s) with 1 file(s) remaining
# Completed 23.3 MiB/23.3 MiB (175.5 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_traces_bupar.csv
# No top sequences found (all sequences are rare)
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_traces_rare_bupar.csv"
# Completed 1.0 MiB/23.3 MiB (13.7 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/23.3 MiB (24.5 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/23.3 MiB (36.2 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/23.3 MiB (43.8 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/23.3 MiB (53.6 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/23.3 MiB (63.0 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/23.3 MiB (72.1 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/23.3 MiB (79.3 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/23.3 MiB (87.0 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/23.3 MiB (94.8 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/23.3 MiB (86.0 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/23.3 MiB (92.0 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/23.3 MiB (98.8 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/23.3 MiB (105.2 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/23.3 MiB (112.2 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/23.3 MiB (118.6 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/23.3 MiB (125.0 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/23.3 MiB (132.1 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/23.3 MiB (137.5 MiB/s) with 1 file(s) remaining
# Completed 20.0 MiB/23.3 MiB (143.5 MiB/s) with 1 file(s) remaining
# Completed 21.0 MiB/23.3 MiB (150.4 MiB/s) with 1 file(s) remaining
# Completed 22.0 MiB/23.3 MiB (155.4 MiB/s) with 1 file(s) remaining
# Completed 23.0 MiB/23.3 MiB (161.6 MiB/s) with 1 file(s) remaining
# Completed 23.3 MiB/23.3 MiB (159.2 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_traces_rare_bupar.csv
# Saved 4206 rare sequences (frequency <= 1)
# Note: process_matrix skipped due to error: missing value where TRUE/FALSE needed
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_process_matrix_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_process_matrix_bupar.csv"
# upload: 3b_feature_importance_eda/outputs/opioid_ed/55_64/features/opioid_ed_55_64_train_target_process_matrix_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/55-64/opioid_ed_55_64_train_target_process_matrix_bupar.csv
# Created overall activity frequency, Gantt timeline (overall + by code type), and activity sequence plots.
#
# === bupaR analysis for opioid_ed 55-64 completed. ===
#
# [OK] All expected BupaR output files created
#
# [INFO] Creating post-target analysis CSV...
# [WARN] Failed to create post-target analysis CSV:
#
#
#
# ✅ BupaR analysis completed successfully

# %% [markdown]
# ### 3. Load and Review BupaR Results

# %%
# Load BupaR results
bupar_results_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_bupar_post_target_analysis.csv"

if bupar_results_path.exists():
    bupar_results = pd.read_csv(bupar_results_path)
    print(f"✅ Loaded BupaR results: {len(bupar_results)} features analyzed")
    
    # Show post-target leakage features
    post_target_leakage = bupar_results[bupar_results.get('is_post_target_leakage', pd.Series([0]*len(bupar_results))) == 1]
    
    print(f"\n📊 BupaR Analysis Summary:")
    print(f"   Total features analyzed: {len(bupar_results)}")
    print(f"   Post-target leakage features: {len(post_target_leakage)}")
    
    if len(post_target_leakage) > 0:
        print(f"\n   ⚠️  Post-target leakage features identified:")
        display(post_target_leakage[['feature', 'is_post_target_leakage']].head(20))
    else:
        print(f"\n   ✅ No post-target leakage features identified")
    
    # Display full results
    print(f"\n   Full BupaR results:")
    display(bupar_results.head(20))
else:
    print(f"❌ BupaR results not found: {bupar_results_path}")
    bupar_results = pd.DataFrame()
# Out:
# ❌ BupaR results not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/25_44/opioid_ed_25_44_bupar_post_target_analysis.csv

# %% [markdown]
# ### 4. View BupaR Visualizations

# %%
# Display BupaR visualizations
bupar_plots = [
    f"{COHORT}_{AGE_BAND_FNAME}_overall_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_milestones_gantt.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_sequence_top.png",
    f"{COHORT}_{AGE_BAND_FNAME}_pre_f1120_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_post_f1120_activity_frequency.png",
]

for plot_name in bupar_plots:
    plot_path = PLOTS_DIR / plot_name
    if plot_path.exists():
        print(f"✅ Displaying: {plot_name}")
        display(Image(str(plot_path)))
    else:
        print(f"⚠️  Plot not found: {plot_path}")

# %% [markdown]
# ## D. Interactive Code Review and Filtering
#
# Review the analysis results and manually add/remove codes that should be filtered before Step 4a.

# %% [markdown]
# ### 1. Review Codes to Filter
#
# Based on the BupaR analyses, review codes that should be filtered:

# %% [markdown]
# ### 2. Manually Add/Remove Codes to Filter
#
# **Instructions:**
# 1. Review the visualizations and analysis results above
# 2. Add codes to filter in the cell below (one per line)
# 3. Remove codes from the filtering list if they should be kept
# 4. Run the cell to update the filtering list

# %%
# ============================================
# MANUAL CODE FILTERING
# ============================================
# Add codes here that you want to filter based on your review
# Format: one code per line as a string

MANUAL_CODES_TO_FILTER = [
    # Example: "Z00.00",  # Administrative code
    # Example: "V70.0",   # Routine exam
    # Add your codes here:
]

# Remove codes from filtering if they should be kept
CODES_TO_KEEP = [
    # Example: "F11.20",  # Keep this code even if flagged
    # Add codes to keep here:
]

# Update filtering recommendations
filtering_recommendations['manual_additional'] = set(MANUAL_CODES_TO_FILTER)

# Remove codes that should be kept
for code in CODES_TO_KEEP:

# Final list of codes to filter
final_codes_to_filter = (

print(f"✅ Updated filtering list")
print(f"   Total codes to filter: {len(final_codes_to_filter)}")
print(f"\n   Codes to filter:")
for code in sorted(final_codes_to_filter):
    print(f"     - {code}")

# Save filtering list to JSON for use in next step
filtering_config = {
    'codes_to_filter': sorted(list(final_codes_to_filter)),
    'codes_to_keep': CODES_TO_KEEP,

filtering_config_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_manual_filtering_config.json"
with open(filtering_config_path, 'w') as f:
    json.dump(filtering_config, f, indent=2)

print(f"\n   💾 Saved filtering config to: {filtering_config_path}")

# %% [markdown]
# ### 1. Update Filtering Scripts (if needed)
#
# If you've added manual codes, you may need to update the filtering scripts to include them. Otherwise, proceed to run the filter and refine step.

# %% [markdown]
# ### 2. Run Filter and Refine

# %%
import subprocess
from datetime import datetime

print("🚀 Filtering and Refining Features...")
print(f"Started at: {datetime.now()}")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "filter_and_refine_features.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ Filter and refine completed successfully")
else:
    print(f"\n❌ Filter and refine failed with return code {result.returncode}")

# %% [markdown]
# ### 3. Review Final Refined Feature Importances

# %%
# Load final refined feature importance
refined_fi_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

if refined_fi_path.exists():
    refined_fi = pd.read_csv(refined_fi_path)
    print(f"✅ Loaded refined feature importance: {len(refined_fi)} features")
    
    # Load filtering summary
    summary_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_feature_filtering_summary.json"
    if summary_path.exists():
        with open(summary_path, 'r') as f:
            filtering_summary = json.load(f)
        
        print(f"\n📊 Filtering Summary:")
        print(f"   Original features: {filtering_summary.get('original_count', 'N/A')}")
        print(f"   Filtered by post-target: {filtering_summary.get('filtered_by_post_target', 0)}")
        print(f"   Filtered by non-value-added: {filtering_summary.get('filtered_by_non_value_added', 0)}")
        print(f"   Filtered by threshold: {filtering_summary.get('filtered_by_threshold', 0)}")
        print(f"   Final features: {filtering_summary.get('final_count', 'N/A')}")
    
    print(f"\n   Top 20 refined features:")
    display(refined_fi.head(20))
    
    print(f"\n   ✅ File ready for Step 4a: {refined_fi_path}")
else:
    print(f"❌ Refined feature importance not found: {refined_fi_path}")

# %% [markdown]
# ### 4. Verify S3 Upload
#
# Check that the refined feature importance file was uploaded to S3 for Step 4a consumption.

# %%
import boto3

s3_client = boto3.client('s3')
s3_bucket = 'pgxdatalake'
s3_key = f"gold/feature_importance/{COHORT}/{AGE_BAND}/{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

try:
    s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    print(f"✅ File exists in S3: s3://{s3_bucket}/{s3_key}")
    
    # Get file size
    response = s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    size_mb = response['ContentLength'] / (1024 * 1024)
    print(f"   File size: {size_mb:.2f} MB")
    print(f"   Last modified: {response['LastModified']}")
except s3_client.exceptions.ClientError as e:
    if e.response['Error']['Code'] == '404':
        print(f"❌ File not found in S3: s3://{s3_bucket}/{s3_key}")
    else:
        print(f"❌ Error checking S3: {e}")

# %% [markdown]
# ## Summary
#
# ✅ **Step 3b Interactive Analysis Complete**
#
# **Outputs Generated:**
# - ✅ BupaR post-target analysis results
# - ✅ Refined `cohort_feature_importance.csv` for Step 4a
# - ✅ Filtering summary JSON
# - ✅ Visualizations (BupaR)
#
# **Next Steps:**
# - Proceed to **Step 4a: Model Data Creation** using the refined feature importances
# - The `cohort_feature_importance.csv` file is available locally and in S3
