# %% [markdown]
# ## Navigation
#
# - **Section A**: Configuration and Setup
# - **Section B**: BupaR Post-Target Analysis (Leakage Detection)
# - **Section C**: Interactive Code Review and Filtering
# - **Section D**: Generate Final Refined Feature Importances

# %% [markdown]
# ## A. Configuration and Setup

# %%
import sys
import os
from pathlib import Path
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image, HTML
import warnings
warnings.filterwarnings('ignore')

# Set project root
PROJECT_ROOT = Path('/home/pgx3874/pgx-analysis')  # Update for your EC2 path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Jupyter environment Python path (update if different)
PYTHON_BIN = Path('/home/pgx3874/jupyter-env/bin/python3.11')  # Full path to Jupyter Python
if not PYTHON_BIN.exists():
    # Fallback to sys.executable if custom path doesn't exist
    PYTHON_BIN = Path(sys.executable)
    print(f"⚠️  Custom Python path not found, using: {PYTHON_BIN}")

# Rscript path for BupaR analysis (update if different)
# The Python script will try to find Rscript automatically, but you can specify it here
# Based on EC2 setup: R is at /usr/local/bin/R, so Rscript is likely at /usr/local/bin/Rscript
RSCRIPT_BIN = Path('/usr/local/bin/Rscript')  # EC2 default location
if not RSCRIPT_BIN.exists():
    # Fallback to None for auto-detection if path doesn't exist
    RSCRIPT_BIN = None
    print(f"⚠️  Rscript not found at {Path('/usr/local/bin/Rscript')}, will use auto-detection")

# Import project utilities
from py_helpers.constants import age_band_to_fname

# Configuration
COHORT = "opioid_ed"  # OPIOID_ED cohort (pre-configured)
AGE_BAND = "45-54"    # Change as needed for different age bands
AGE_BAND_FNAME = age_band_to_fname(AGE_BAND)

# Output directories
OUTPUT_DIR = PROJECT_ROOT / "3b_feature_importance_eda" / "outputs" / COHORT / AGE_BAND_FNAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PLOTS_DIR = OUTPUT_DIR / "plots"
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

print(f"✅ Configuration loaded")
print(f"   Cohort: {COHORT}")
print(f"   Age Band: {AGE_BAND} ({AGE_BAND_FNAME})")
print(f"   Python Binary: {PYTHON_BIN}")
if RSCRIPT_BIN:
    print(f"   Rscript Binary: {RSCRIPT_BIN}")
else:
    print(f"   Rscript Binary: Auto-detect (will be found by script)")
print(f"   Output Directory: {OUTPUT_DIR}")
# Out:
# ✅ Configuration loaded
#    Cohort: opioid_ed
#    Age Band: 45-54 (45_54)
#    Python Binary: /home/pgx3874/jupyter-env/bin/python3.11
#    Rscript Binary: /usr/local/bin/Rscript
#    Output Directory: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54

# %% [markdown]
# ### 1. Load Aggregated Feature Importances from Step 3

# %%
# Load aggregated feature importance from Step 3
possible_paths = [
    PROJECT_ROOT / "3_feature_importance" / "outputs" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
    PROJECT_ROOT / "3_feature_importance" / "from_s3" / "by_cohort" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
]

aggregated_fi = None
for path in possible_paths:
    if path.exists():
        aggregated_fi = pd.read_csv(path)
        print(f"✅ Loaded aggregated feature importance from: {path}")
        print(f"   Total features: {len(aggregated_fi):,}")
        break

if aggregated_fi is None:
    print(f"❌ Could not find aggregated feature importance file")
    print(f"   Checked paths:")
    for path in possible_paths:
        print(f"     - {path}")
else:
    # Display summary
    print(f"\n📊 Feature Importance Summary:")
    print(f"   Columns: {list(aggregated_fi.columns)}")
    print(f"\n   Top 10 features:")
    display(aggregated_fi.head(10))
# Out:
# ✅ Loaded aggregated feature importance from: /home/pgx3874/pgx-analysis/3_feature_importance/outputs/opioid_ed/45-54/opioid_ed_45_54_aggregated_feature_importance.csv
#    Total features: 3,534
#
# 📊 Feature Importance Summary:
#    Columns: ['feature', 'importance_normalized', 'importance_scaled', 'n_models']
#
#    Top 10 features:
#                           feature  importance_normalized  importance_scaled  \
# 0                      item_H0020               1.000000           0.832821
# 1                      item_80307               0.760469           0.633335
# 2                   item_SUBOXONE               0.671860           0.559539
# 3                      item_G0483               0.320470           0.266894
# 4                      item_S0109               0.227590           0.189542
# 5                      item_80305               0.188757           0.157201
# 6  item_BUPRENORPHINE HCL/NALOXON               0.151457           0.126136
# 7                      item_82075               0.121624           0.101291
# 8                      item_99396               0.115665           0.096328
# 9                      item_G0480               0.102577           0.085428
#
#    n_models
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# 5         3
# 6         3
# 7         3
# 8         3
# 9         3

# %% [markdown]
# ## C. BupaR Post-Target Analysis (Leakage Detection)
#
# BupaR analysis identifies features that appear primarily after the target event (potential leakage).

# %% [markdown]
# ### 1. Verify Rscript is Available
#
# **Note:** BupaR analysis uses R scripts, so Rscript must be installed and available in PATH. The Python script will automatically find Rscript, but you can verify it's available here.

# %%
# Verify Rscript is available
import shutil
import subprocess

# Check configured path first
if RSCRIPT_BIN and RSCRIPT_BIN.exists():
    print(f"✅ Rscript found at configured path: {RSCRIPT_BIN}")
    rscript_path = str(RSCRIPT_BIN)
else:
    # Try to find in PATH
    rscript_path = shutil.which("Rscript")
    if rscript_path:
        print(f"✅ Rscript found in PATH: {rscript_path}")
    else:
        # Try common EC2 locations
        common_paths = [
            Path('/usr/local/bin/Rscript'),  # EC2 default
            Path('/usr/bin/Rscript'),
        ]
        found = False
        for path in common_paths:
            if path.exists():
                print(f"✅ Rscript found at: {path}")
                rscript_path = str(path)
                found = True
                break
        if not found:
            print(f"⚠️  Rscript not found")
            print(f"   The Python script will try to find it automatically")
            rscript_path = None

# Check version if found
if rscript_path:
    try:
        result = subprocess.run([rscript_path, "--version"], capture_output=True, text=True, timeout=5)
        if result.returncode == 0:
            version_line = result.stdout.strip().split('\n')[0] if result.stdout else "Unknown"
            print(f"   Version: {version_line}")
    except Exception as e:
        print(f"   Could not check version: {e}")

print("\n" + "="*80)
# Out:
# ✅ Rscript found at configured path: /usr/local/bin/Rscript
#    Version: Rscript (R) version 4.4.3 (2025-02-28)
#
# ================================================================================

# %% [markdown]
# ### 2. Run BupaR Post-Target Analysis
#
# **Note:** This Python script calls R scripts (`create_bupar_outputs_*.R`) using Rscript. The script automatically finds Rscript, so no manual configuration is needed.

# %%
import subprocess
from datetime import datetime

print("🚀 Running BupaR Post-Target Analysis...")
print(f"Started at: {datetime.now()}")
print(f"Note: This will call R scripts using Rscript")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "run_bupar_post_target_analysis.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ BupaR analysis completed successfully")
else:
    print(f"\n❌ BupaR analysis failed with return code {result.returncode}")
    if "Rscript not found" in result.stderr or "Rscript not found" in result.stdout:
        print("\n💡 Tip: Make sure R is installed and Rscript is in your PATH")
        print("   Or set RSCRIPT_BIN in the configuration cell above")
# Out:
# 🚀 Running BupaR Post-Target Analysis...
# Started at: 2026-01-18 02:24:14.572705
# Note: This will call R scripts using Rscript
#
# ================================================================================
# BupaR Analysis: opioid_ed / 45-54
# ================================================================================
# [INFO] Using Rscript: /usr/local/bin/Rscript
# [INFO] Running: /usr/local/bin/Rscript /home/pgx3874/pgx-analysis/3b_feature_importance_eda/1_bupaR/create_bupar_outputs_opioid_ed.R 45-54
# [INFO] Working directory: /home/pgx3874/pgx-analysis
# [OK] R script completed successfully
# R Output:
# === bupaR Analysis: Cohort 1 (OPIOID_ED) ===
#   Age band:       45-54
#   Control cohort: non_opioid_ed
#
# Project root:         /home/pgx3874/pgx-analysis
# Model data path:      /mnt/nvme/4a_model_data/cohort_name=opioid_ed/age_band=45-54/model_events.parquet
# Note: Using all codes from model_data (FP-Growth filtering removed)
#
# Loaded 5153251 events for opioid_ed age_band=45-54 across years 2016,2017,2018
# Target=1 rows: 1144928
# Target eventlog created.
# # Log of 1766783 events consisting of:
# 4259 cases
# 1766783 instances of 10812 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,766,783 × 7
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1011539802 DRUG:GABAPE… 2016-01-01 00:00:00                    1 complete
#  2 1011539802 DRUG:AZITHR… 2016-01-08 00:00:00                    2 complete
#  3 1011539802 DRUG:CLONAZ… 2016-01-20 00:00:00                    3 complete
#  4 1011539802 DRUG:METFOR… 2016-02-01 00:00:00                    4 complete
#  5 1011539802 DRUG:DIVALP… 2016-02-01 00:00:00                    5 complete
#  6 1011539802 DRUG:GABAPE… 2016-02-01 00:00:00                    6 complete
#  7 1011539802 DRUG:OMEPRA… 2016-02-01 00:00:00                    7 complete
#  8 1011539802 DRUG:ATORVA… 2016-02-01 00:00:00                    8 complete
#  9 1011539802 DRUG:JANUVIA 2016-02-01 00:00:00                    9 complete
# 10 1011539802 DRUG:FENOFI… 2016-02-01 00:00:00                   10 complete
# # ℹ 1,766,773 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
# Combined TARGET + CONTROL sankey_eventlog created.
# # Log of 1766783 events consisting of:
# 4259 cases
# 1766783 instances of 10812 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,766,783 × 8
#    case_id  activity timestamp           group activity_instance_id lifecycle_id
#    <chr>    <chr>    <dttm>              <chr>                <int> <chr>
#  1 1011539… DRUG:GA… 2016-01-01 00:00:00 targ…                    1 complete
#  2 1011539… DRUG:AZ… 2016-01-08 00:00:00 targ…                    2 complete
#  3 1011539… DRUG:CL… 2016-01-20 00:00:00 targ…                    3 complete
#  4 1011539… DRUG:ME… 2016-02-01 00:00:00 targ…                    4 complete
#  5 1011539… DRUG:DI… 2016-02-01 00:00:00 targ…                    5 complete
#  6 1011539… DRUG:GA… 2016-02-01 00:00:00 targ…                    6 complete
#  7 1011539… DRUG:OM… 2016-02-01 00:00:00 targ…                    7 complete
#  8 1011539… DRUG:AT… 2016-02-01 00:00:00 targ…                    8 complete
#  9 1011539… DRUG:JA… 2016-02-01 00:00:00 targ…                    9 complete
# 10 1011539… DRUG:FE… 2016-02-01 00:00:00 targ…                   10 complete
# # ℹ 1,766,773 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
#
# --- Pre-F1120 (before first ICD:F1120) analysis ---
# Pre-F1120 eventlog summary:
# # Log of 482420 events consisting of:
# 3825 cases
# 482420 instances of 7323 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 482,420 × 11
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1000001044 DRUG:MELOXI… 2017-01-20 00:00:00                    1 complete
#  2 1000001044 DRUG:PRAVAS… 2017-01-20 00:00:00                    2 complete
#  3 1000001044 ICD:M62830   2017-01-20 00:00:00                    3 complete
#  4 1000001044 CPT:99214    2017-01-20 00:00:00                    4 complete
#  5 1000001044 DRUG:CYCLOB… 2017-01-23 00:00:00                    5 complete
#  6 1000001044 DRUG:HYDROX… 2017-01-24 00:00:00                    6 complete
#  7 1000001044 DRUG:QUETIA… 2017-01-24 00:00:00                    7 complete
#  8 1000001044 DRUG:CITALO… 2017-01-24 00:00:00                    8 complete
#  9 1000001044 DRUG:BUPROP… 2017-01-24 00:00:00                    9 complete
# 10 1000001044 DRUG:IBUPRO… 2017-02-02 00:00:00                   10 complete
# # ℹ 482,410 more rows
# # ℹ 6 more variables: resource_id <chr>, .order <int>, event_index <int>,
# #   is_target_icd <lgl>, has_target <lgl>, first_target_index <int>
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_traces_bupar.csv"
# Completed 1.0 MiB/6.1 MiB (57.3 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/6.1 MiB (35.3 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/6.1 MiB (50.9 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/6.1 MiB (66.3 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/6.1 MiB (81.5 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/6.1 MiB (96.3 MiB/s) with 1 file(s) remaining
# Completed 6.1 MiB/6.1 MiB (41.8 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_traces_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_traces_rare_bupar.csv"
# Completed 1.0 MiB/6.2 MiB (78.2 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/6.2 MiB (42.3 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/6.2 MiB (61.1 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/6.2 MiB (78.8 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/6.2 MiB (95.7 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/6.2 MiB (99.5 MiB/s) with 1 file(s) remaining
# Completed 6.2 MiB/6.2 MiB (41.5 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_traces_rare_bupar.csv
# Saved 3731 rare pre-F1120 sequences (frequency <= 1)
# Sample pre-F1120 drug-only sequences:
# # A tibble: 6 × 2
#   case_id    drug_sequence
#   <chr>      <list>
# 1 1000001044 <chr [45]>
# 2 1000004610 <chr [95]>
# 3 1000006292 <chr [25]>
# 4 1000009409 <chr [37]>
# 5 1000010547 <chr [92]>
# 6 1000011707 <chr [30]>
# Created pre-F1120 activity frequency and Gantt timeline plots (overall + by code type).
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_patient_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_patient_features_bupar.csv"
# Completed 94.5 KiB/94.5 KiB (1.4 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_pre_f1120_patient_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_pre_f1120_patient_features_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_time_to_f1120_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_time_to_f1120_features_bupar.csv"
# Completed 328.6 KiB/328.6 KiB (21.4 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_time_to_f1120_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_time_to_f1120_features_bupar.csv
#
# --- Post-F1120 (after first ICD:F1120) analysis ---
# Post-F1120 eventlog summary:
# # Log of 1263156 events consisting of:
# 4195 cases
# 1263156 instances of 9219 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,263,156 × 11
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1000001044 CPT:99214    2017-11-08 00:00:00                    1 complete
#  2 1000001044 DRUG:LATUDA  2017-11-30 00:00:00                    2 complete
#  3 1000001044 DRUG:LISINO… 2017-11-30 00:00:00                    3 complete
#  4 1000001044 DRUG:BUPROP… 2017-11-30 00:00:00                    4 complete
#  5 1000001044 DRUG:METOPR… 2017-11-30 00:00:00                    5 complete
#  6 1000001044 DRUG:HYDROX… 2017-11-30 00:00:00                    6 complete
#  7 1000001044 DRUG:PRAVAS… 2017-11-30 00:00:00                    7 complete
#  8 1000001044 DRUG:FLUOXE… 2017-11-30 00:00:00                    8 complete
#  9 1000001044 DRUG:MELOXI… 2017-11-30 00:00:00                    9 complete
# 10 1000001044 ICD:F251     2017-11-30 00:00:00                   10 complete
# # ℹ 1,263,146 more rows
# # ℹ 6 more variables: resource_id <chr>, .order <int>, event_index <int>,
# #   is_target_icd <lgl>, has_target <lgl>, first_target_index <int>
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_traces_bupar.csv"
# Completed 1.0 MiB/15.9 MiB (13.0 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/15.9 MiB (22.9 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/15.9 MiB (30.7 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/15.9 MiB (40.0 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/15.9 MiB (49.1 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/15.9 MiB (58.0 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/15.9 MiB (66.3 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/15.9 MiB (74.2 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/15.9 MiB (82.0 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/15.9 MiB (72.3 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/15.9 MiB (76.5 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/15.9 MiB (82.7 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/15.9 MiB (89.0 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/15.9 MiB (95.3 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/15.9 MiB (101.5 MiB/s) with 1 file(s) remaining
# Completed 15.9 MiB/15.9 MiB (107.1 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_traces_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_traces_rare_bupar.csv"
# Completed 1.0 MiB/15.9 MiB (13.5 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/15.9 MiB (23.9 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/15.9 MiB (30.5 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/15.9 MiB (39.4 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/15.9 MiB (47.6 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/15.9 MiB (55.7 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/15.9 MiB (63.8 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/15.9 MiB (70.7 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/15.9 MiB (77.5 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/15.9 MiB (78.6 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/15.9 MiB (84.3 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/15.9 MiB (90.3 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/15.9 MiB (95.8 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/15.9 MiB (101.9 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/15.9 MiB (107.4 MiB/s) with 1 file(s) remaining
# Completed 15.9 MiB/15.9 MiB (112.2 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_traces_rare_bupar.csv
# Saved 4144 rare post-F1120 sequences (frequency <= 1)
# Created post-F1120 activity frequency and Gantt timeline plots (overall + by code type).
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_patient_features_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_patient_features_bupar.csv"
# Completed 111.2 KiB/111.2 KiB (1.1 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_post_f1120_patient_features_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_post_f1120_patient_features_bupar.csv
#
# --- Target-only global process mining ---
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_traces_bupar.csv"
# Completed 1.0 MiB/22.2 MiB (7.2 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/22.2 MiB (13.4 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/22.2 MiB (19.9 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/22.2 MiB (24.7 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/22.2 MiB (30.6 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/22.2 MiB (36.6 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/22.2 MiB (42.1 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/22.2 MiB (47.6 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/22.2 MiB (53.2 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/22.2 MiB (58.6 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/22.2 MiB (55.9 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/22.2 MiB (60.7 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/22.2 MiB (65.4 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/22.2 MiB (70.2 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/22.2 MiB (74.9 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/22.2 MiB (79.6 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/22.2 MiB (84.4 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/22.2 MiB (89.1 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/22.2 MiB (93.9 MiB/s) with 1 file(s) remaining
# Completed 20.0 MiB/22.2 MiB (98.3 MiB/s) with 1 file(s) remaining
# Completed 21.0 MiB/22.2 MiB (102.3 MiB/s) with 1 file(s) remaining
# Completed 22.0 MiB/22.2 MiB (106.3 MiB/s) with 1 file(s) remaining
# Completed 22.2 MiB/22.2 MiB (77.9 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_traces_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_traces_bupar.csv
# No top sequences found (all sequences are rare)
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_traces_rare_bupar.csv"
# Completed 1.0 MiB/22.2 MiB (14.3 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/22.2 MiB (25.2 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/22.2 MiB (37.3 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/22.2 MiB (44.7 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/22.2 MiB (54.8 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/22.2 MiB (63.8 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/22.2 MiB (73.1 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/22.2 MiB (82.0 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/22.2 MiB (90.2 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/22.2 MiB (97.9 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/22.2 MiB (91.7 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/22.2 MiB (97.9 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/22.2 MiB (105.1 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/22.2 MiB (112.4 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/22.2 MiB (119.2 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/22.2 MiB (126.1 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/22.2 MiB (133.9 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/22.2 MiB (140.4 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/22.2 MiB (147.6 MiB/s) with 1 file(s) remaining
# Completed 20.0 MiB/22.2 MiB (154.8 MiB/s) with 1 file(s) remaining
# Completed 21.0 MiB/22.2 MiB (161.4 MiB/s) with 1 file(s) remaining
# Completed 22.0 MiB/22.2 MiB (167.8 MiB/s) with 1 file(s) remaining
# Completed 22.2 MiB/22.2 MiB (125.5 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_traces_rare_bupar.csv
# Saved 4250 rare sequences (frequency <= 1)
# Note: process_matrix skipped due to error: missing value where TRUE/FALSE needed
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_process_matrix_bupar.csv" "s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_process_matrix_bupar.csv"
# upload: 3b_feature_importance_eda/outputs/opioid_ed/45_54/features/opioid_ed_45_54_train_target_process_matrix_bupar.csv to s3://pgxdatalake/gold/bupar/opioid_ed/45-54/opioid_ed_45_54_train_target_process_matrix_bupar.csv
# Created overall activity frequency, Gantt timeline (overall + by code type), and activity sequence plots.
#
# === bupaR analysis for opioid_ed 45-54 completed. ===
#
# [OK] All expected BupaR output files created
#
# [INFO] Creating post-target analysis CSV...
# [WARN] Failed to create post-target analysis CSV:
#
#
#
# ✅ BupaR analysis completed successfully

# %% [markdown]
# ### 3. Load and Review BupaR Results

# %%
# Load BupaR results
bupar_results_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_bupar_post_target_analysis.csv"

if bupar_results_path.exists():
    bupar_results = pd.read_csv(bupar_results_path)
    print(f"✅ Loaded BupaR results: {len(bupar_results)} features analyzed")
    
    # Show post-target leakage features
    post_target_leakage = bupar_results[bupar_results.get('is_post_target_leakage', pd.Series([0]*len(bupar_results))) == 1]
    
    print(f"\n📊 BupaR Analysis Summary:")
    print(f"   Total features analyzed: {len(bupar_results)}")
    print(f"   Post-target leakage features: {len(post_target_leakage)}")
    
    if len(post_target_leakage) > 0:
        print(f"\n   ⚠️  Post-target leakage features identified:")
        display(post_target_leakage[['feature', 'is_post_target_leakage']].head(20))
    else:
        print(f"\n   ✅ No post-target leakage features identified")
    
    # Display full results
    print(f"\n   Full BupaR results:")
    display(bupar_results.head(20))
else:
    print(f"❌ BupaR results not found: {bupar_results_path}")
    bupar_results = pd.DataFrame()
# Out:
# ❌ BupaR results not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/opioid_ed/25_44/opioid_ed_25_44_bupar_post_target_analysis.csv

# %% [markdown]
# ### 4. View BupaR Visualizations

# %%
# Display BupaR visualizations
bupar_plots = [
    f"{COHORT}_{AGE_BAND_FNAME}_overall_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_milestones_gantt.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_sequence_top.png",
    f"{COHORT}_{AGE_BAND_FNAME}_pre_f1120_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_post_f1120_activity_frequency.png",
]

# Check if plots directory exists and list available plots
if PLOTS_DIR.exists():
    available_plots = list(PLOTS_DIR.glob("*.png"))
    print(f"📁 Plots directory: {PLOTS_DIR}")
    print(f"   Found {len(available_plots)} PNG files")
    if available_plots:
        print(f"   Available plots:")
        for p in sorted(available_plots):
            print(f"     - {p.name}")
else:
    print(f"⚠️  Plots directory does not exist: {PLOTS_DIR}")

print(f"\n🔍 Looking for BupaR plots...")
for plot_name in bupar_plots:
    plot_path = PLOTS_DIR / plot_name
    if plot_path.exists():
        print(f"✅ Displaying: {plot_name}")
        display(Image(str(plot_path)))
    else:
        print(f"⚠️  Plot not found: {plot_path}")
        # Try alternative path (in case plots are in features/ subdirectory)
        alt_path = OUTPUT_DIR / "features" / plot_name
        if alt_path.exists():
            print(f"   Found in alternative location: {alt_path}")
            display(Image(str(alt_path)))
        else:
            # Try without cohort prefix (in case R script saved without it)
            simple_name = plot_name.replace(f"{COHORT}_{AGE_BAND_FNAME}_", "")
            simple_path = PLOTS_DIR / simple_name
            if simple_path.exists():
                print(f"   Found with simple name: {simple_path}")
                display(Image(str(simple_path)))

# %% [markdown]
# ## D. Interactive Code Review and Filtering
#
# Review the analysis results and manually add/remove codes that should be filtered before Step 4a.

# %% [markdown]
# ### 1. Review Codes to Filter
#
# Based on the BupaR analyses, review codes that should be filtered:

# %% [markdown]
# ### 2. Manually Add/Remove Codes to Filter
#
# **Instructions:**
# 1. Review the visualizations and analysis results above
# 2. Add codes to filter in the cell below (one per line)
# 3. Remove codes from the filtering list if they should be kept
# 4. Run the cell to update the filtering list

# %%
# ============================================
# MANUAL CODE FILTERING
# ============================================
# Add codes here that you want to filter based on your review
# Format: one code per line as a string

MANUAL_CODES_TO_FILTER = [
    # Example: "Z00.00",  # Administrative code
    # Example: "V70.0",   # Routine exam
    # Add your codes here:
]

# Remove codes from filtering if they should be kept
CODES_TO_KEEP = [
    # Example: "F11.20",  # Keep this code even if flagged
    # Add codes to keep here:
]

# Update filtering recommendations
filtering_recommendations['manual_additional'] = set(MANUAL_CODES_TO_FILTER)

# Remove codes that should be kept
for code in CODES_TO_KEEP:

# Final list of codes to filter
final_codes_to_filter = (

print(f"✅ Updated filtering list")
print(f"   Total codes to filter: {len(final_codes_to_filter)}")
print(f"\n   Codes to filter:")
for code in sorted(final_codes_to_filter):
    print(f"     - {code}")

# Save filtering list to JSON for use in next step
filtering_config = {
    'codes_to_filter': sorted(list(final_codes_to_filter)),
    'codes_to_keep': CODES_TO_KEEP,

filtering_config_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_manual_filtering_config.json"
with open(filtering_config_path, 'w') as f:
    json.dump(filtering_config, f, indent=2)

print(f"\n   💾 Saved filtering config to: {filtering_config_path}")

# %% [markdown]
# ### 1. Update Filtering Scripts (if needed)
#
# If you've added manual codes, you may need to update the filtering scripts to include them. Otherwise, proceed to run the filter and refine step.

# %% [markdown]
# ### 2. Run Filter and Refine

# %%
import subprocess
from datetime import datetime

print("🚀 Filtering and Refining Features...")
print(f"Started at: {datetime.now()}")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "filter_and_refine_features.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ Filter and refine completed successfully")
else:
    print(f"\n❌ Filter and refine failed with return code {result.returncode}")

# %% [markdown]
# ### 3. Review Final Refined Feature Importances

# %%
# Load final refined feature importance
refined_fi_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

if refined_fi_path.exists():
    refined_fi = pd.read_csv(refined_fi_path)
    print(f"✅ Loaded refined feature importance: {len(refined_fi)} features")
    
    # Load filtering summary
    summary_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_feature_filtering_summary.json"
    if summary_path.exists():
        with open(summary_path, 'r') as f:
            filtering_summary = json.load(f)
        
        print(f"\n📊 Filtering Summary:")
        print(f"   Original features: {filtering_summary.get('original_count', 'N/A')}")
        print(f"   Filtered by post-target: {filtering_summary.get('filtered_by_post_target', 0)}")
        print(f"   Filtered by non-value-added: {filtering_summary.get('filtered_by_non_value_added', 0)}")
        print(f"   Filtered by threshold: {filtering_summary.get('filtered_by_threshold', 0)}")
        print(f"   Final features: {filtering_summary.get('final_count', 'N/A')}")
    
    print(f"\n   Top 20 refined features:")
    display(refined_fi.head(20))
    
    print(f"\n   ✅ File ready for Step 4a: {refined_fi_path}")
else:
    print(f"❌ Refined feature importance not found: {refined_fi_path}")

# %% [markdown]
# ### 4. Verify S3 Upload
#
# Check that the refined feature importance file was uploaded to S3 for Step 4a consumption.

# %%
import boto3

s3_client = boto3.client('s3')
s3_bucket = 'pgxdatalake'
s3_key = f"gold/feature_importance/{COHORT}/{AGE_BAND}/{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

try:
    s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    print(f"✅ File exists in S3: s3://{s3_bucket}/{s3_key}")
    
    # Get file size
    response = s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    size_mb = response['ContentLength'] / (1024 * 1024)
    print(f"   File size: {size_mb:.2f} MB")
    print(f"   Last modified: {response['LastModified']}")
except s3_client.exceptions.ClientError as e:
    if e.response['Error']['Code'] == '404':
        print(f"❌ File not found in S3: s3://{s3_bucket}/{s3_key}")
    else:
        print(f"❌ Error checking S3: {e}")

# %% [markdown]
# ## Summary
#
# ✅ **Step 3b Interactive Analysis Complete**
#
# **Outputs Generated:**
# - ✅ BupaR post-target analysis results
# - ✅ Refined `cohort_feature_importance.csv` for Step 4a
# - ✅ Filtering summary JSON
# - ✅ Visualizations (BupaR)
#
# **Next Steps:**
# - Proceed to **Step 4a: Model Data Creation** using the refined feature importances
# - The `cohort_feature_importance.csv` file is available locally and in S3
