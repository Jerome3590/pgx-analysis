# %% [markdown]
# ## Navigation
#
# - **Section A**: Configuration and Setup
# - **Section B**: BupaR Post-Target Analysis (Leakage Detection)
# - **Section C**: Interactive Code Review and Filtering
# - **Section D**: Generate Final Refined Feature Importances

# %% [markdown]
# ## A. Configuration and Setup

# %%
import sys
import os
from pathlib import Path
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image, HTML
import warnings
warnings.filterwarnings('ignore')

# Set project root
PROJECT_ROOT = Path('/home/pgx3874/pgx-analysis')  # Update for your EC2 path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Jupyter environment Python path (update if different)
PYTHON_BIN = Path('/home/pgx3874/jupyter-env/bin/python3.11')  # Full path to Jupyter Python
if not PYTHON_BIN.exists():
    # Fallback to sys.executable if custom path doesn't exist
    PYTHON_BIN = Path(sys.executable)
    print(f"⚠️  Custom Python path not found, using: {PYTHON_BIN}")

# Rscript path for BupaR analysis (update if different)
# The Python script will try to find Rscript automatically, but you can specify it here
# Based on EC2 setup: R is at /usr/local/bin/R, so Rscript is likely at /usr/local/bin/Rscript
RSCRIPT_BIN = Path('/usr/local/bin/Rscript')  # EC2 default location
if not RSCRIPT_BIN.exists():
    # Fallback to None for auto-detection if path doesn't exist
    RSCRIPT_BIN = None
    print(f"⚠️  Rscript not found at {Path('/usr/local/bin/Rscript')}, will use auto-detection")

# Import project utilities
from py_helpers.constants import age_band_to_fname

# Configuration
COHORT = "non_opioid_ed"  # NON_OPIOID_ED cohort (pre-configured)
AGE_BAND = "85-94"    # Change as needed for different age bands
AGE_BAND_FNAME = age_band_to_fname(AGE_BAND)

# Output directories
OUTPUT_DIR = PROJECT_ROOT / "3b_feature_importance_eda" / "outputs" / COHORT / AGE_BAND_FNAME
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PLOTS_DIR = OUTPUT_DIR / "plots"
PLOTS_DIR.mkdir(parents=True, exist_ok=True)

print(f"✅ Configuration loaded")
print(f"   Cohort: {COHORT}")
print(f"   Age Band: {AGE_BAND} ({AGE_BAND_FNAME})")
print(f"   Python Binary: {PYTHON_BIN}")
if RSCRIPT_BIN:
    print(f"   Rscript Binary: {RSCRIPT_BIN}")
else:
    print(f"   Rscript Binary: Auto-detect (will be found by script)")
print(f"   Output Directory: {OUTPUT_DIR}")
# Out:
# ✅ Configuration loaded
#    Cohort: non_opioid_ed
#    Age Band: 85-94 (85_94)
#    Python Binary: /home/pgx3874/jupyter-env/bin/python3.11
#    Rscript Binary: /usr/local/bin/Rscript
#    Output Directory: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94

# %% [markdown]
# ### 1. Load Aggregated Feature Importances from Step 3

# %%
# Load aggregated feature importance from Step 3
possible_paths = [
    PROJECT_ROOT / "3_feature_importance" / "outputs" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
    PROJECT_ROOT / "3_feature_importance" / "from_s3" / "by_cohort" / COHORT / AGE_BAND / f"{COHORT}_{AGE_BAND_FNAME}_aggregated_feature_importance.csv",
]

aggregated_fi = None
for path in possible_paths:
    if path.exists():
        aggregated_fi = pd.read_csv(path)
        print(f"✅ Loaded aggregated feature importance from: {path}")
        print(f"   Total features: {len(aggregated_fi):,}")
        break

if aggregated_fi is None:
    print(f"❌ Could not find aggregated feature importance file")
    print(f"   Checked paths:")
    for path in possible_paths:
        print(f"     - {path}")
else:
    # Display summary
    print(f"\n📊 Feature Importance Summary:")
    print(f"   Columns: {list(aggregated_fi.columns)}")
    print(f"\n   Top 10 features:")
    display(aggregated_fi.head(10))
# Out:
# ✅ Loaded aggregated feature importance from: /home/pgx3874/pgx-analysis/3_feature_importance/outputs/non_opioid_ed/85-94/non_opioid_ed_85_94_aggregated_feature_importance.csv
#    Total features: 848
#
# 📊 Feature Importance Summary:
#    Columns: ['feature', 'importance_normalized', 'importance_scaled', 'n_models', 'models']
#
#    Top 10 features:
#                           feature  importance_normalized  importance_scaled  \
# 0                 item_FUROSEMIDE               1.000000           0.133870
# 1                 item_CEPHALEXIN               0.610189           0.081686
# 2                 item_PREDNISONE               0.467950           0.062645
# 3  item_HYDROCODONE BITARTRATE/AC               0.433264           0.058001
# 4                    item_ELIQUIS               0.363214           0.048624
# 5               item_TRAMADOL HCL               0.363158           0.048616
# 6            item_WARFARIN SODIUM               0.297555           0.039834
# 7        item_PANTOPRAZOLE SODIUM               0.293840           0.039336
# 8            item_ONDANSETRON ODT               0.249355           0.033381
# 9  item_NITROFURANTOIN MONOHYDRAT               0.242696           0.032490
#
#    n_models                       models
# 0         3  catboost,xgboost,xgboost_rf
# 1         3  catboost,xgboost,xgboost_rf
# 2         3  catboost,xgboost,xgboost_rf
# 3         3  catboost,xgboost,xgboost_rf
# 4         3  catboost,xgboost,xgboost_rf
# 5         3  catboost,xgboost,xgboost_rf
# 6         3  catboost,xgboost,xgboost_rf
# 7         3  catboost,xgboost,xgboost_rf
# 8         3  catboost,xgboost,xgboost_rf
# 9         3  catboost,xgboost,xgboost_rf

# %% [markdown]
# ## C. BupaR Post-Target Analysis (Leakage Detection)
#
# BupaR analysis identifies features that appear primarily after the target event (potential leakage).

# %% [markdown]
# ### 1. Verify Rscript is Available
#
# **Note:** BupaR analysis uses R scripts, so Rscript must be installed and available in PATH. The Python script will automatically find Rscript, but you can verify it's available here.

# %%
# Verify Rscript is available
import shutil
import subprocess

# Check configured path first
if RSCRIPT_BIN and RSCRIPT_BIN.exists():
    print(f"✅ Rscript found at configured path: {RSCRIPT_BIN}")
    rscript_path = str(RSCRIPT_BIN)
else:
    # Try to find in PATH
    rscript_path = shutil.which("Rscript")
    if rscript_path:
        print(f"✅ Rscript found in PATH: {rscript_path}")
    else:
        # Try common EC2 locations
        common_paths = [
            Path('/usr/local/bin/Rscript'),  # EC2 default
            Path('/usr/bin/Rscript'),
        ]
        found = False
        for path in common_paths:
            if path.exists():
                print(f"✅ Rscript found at: {path}")
                rscript_path = str(path)
                found = True
                break
        if not found:
            print(f"⚠️  Rscript not found")
            print(f"   The Python script will try to find it automatically")
            rscript_path = None

# Check version if found
if rscript_path:
    try:
        result = subprocess.run([rscript_path, "--version"], capture_output=True, text=True, timeout=5)
        if result.returncode == 0:
            version_line = result.stdout.strip().split('\n')[0] if result.stdout else "Unknown"
            print(f"   Version: {version_line}")
    except Exception as e:
        print(f"   Could not check version: {e}")

print("\n" + "="*80)
# Out:
# ✅ Rscript found at configured path: /usr/local/bin/Rscript
#    Version: Rscript (R) version 4.4.3 (2025-02-28)
#
# ================================================================================

# %% [markdown]
# ### 2. Run BupaR Post-Target Analysis
#
# **Note:** This Python script calls R scripts (`create_bupar_outputs_*.R`) using Rscript. The script automatically finds Rscript, so no manual configuration is needed.

# %%
import subprocess
from datetime import datetime

print("🚀 Running BupaR Post-Target Analysis...")
print(f"Started at: {datetime.now()}")
print(f"Note: This will call R scripts using Rscript")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "run_bupar_post_target_analysis.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ BupaR analysis completed successfully")
else:
    print(f"\n❌ BupaR analysis failed with return code {result.returncode}")
    if "Rscript not found" in result.stderr or "Rscript not found" in result.stdout:
        print("\n💡 Tip: Make sure R is installed and Rscript is in your PATH")
        print("   Or set RSCRIPT_BIN in the configuration cell above")
# Out:
# 🚀 Running BupaR Post-Target Analysis...
# Started at: 2026-01-19 02:57:37.069885
# Note: This will call R scripts using Rscript
#
# ================================================================================
# BupaR Analysis: non_opioid_ed / 85-94
# ================================================================================
# [INFO] Using Rscript: /usr/local/bin/Rscript
# [INFO] Running: /usr/local/bin/Rscript /home/pgx3874/pgx-analysis/3b_feature_importance_eda/1_bupaR/create_bupar_outputs_non_opioid_ed.R 85-94
# [INFO] Working directory: /home/pgx3874/pgx-analysis
# [OK] R script completed successfully
# R Output:
# === bupaR Analysis: Cohort 2 (POLYPHARMACY_ED, non_opioid_ed) ===
#   Age band:       85-94
#   Control cohort: non_opioid_non_ed
#
# Project root:         /home/pgx3874/pgx-analysis
# Data root:            /mnt/nvme
# Model data path:      /mnt/nvme/4a_model_data/cohort_name=non_opioid_ed/age_band=85-94/model_events.parquet
# Note: Using all codes from model_events.parquet
#
# Loaded 11905557 events for non_opioid_ed age_band=85-94 across years 2016,2017,2018
# Target=1 rows: 924347
# Target eventlog created.
# # Log of 1133062 events consisting of:
# 67208 cases
# 1133062 instances of 2716 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,133,062 × 7
#    case_id    activity    timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>       <dttm>                             <int> <chr>
#  1 1003613890 ICD:Unknown 2018-04-16 00:00:00                    1 complete
#  2 1003613890 CPT:86334   2018-04-16 00:00:00                    2 complete
#  3 1003613890 ICD:Unknown 2018-04-16 00:00:00                    3 complete
#  4 1003613890 CPT:82784   2018-04-16 00:00:00                    4 complete
#  5 1003613890 ICD:Unknown 2018-04-16 00:00:00                    5 complete
#  6 1003613890 CPT:99213   2018-04-16 00:00:00                    6 complete
#  7 1003613890 ICD:Unknown 2018-04-16 00:00:00                    7 complete
#  8 1003613890 CPT:84165   2018-04-16 00:00:00                    8 complete
#  9 1003613890 ICD:Unknown 2018-04-16 00:00:00                    9 complete
# 10 1003613890 CPT:82784   2018-04-16 00:00:00                   10 complete
# # ℹ 1,133,052 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
# ⚠️  Control cohort file exists but is too small/corrupted (0 bytes). Will recreate.
#
# ⚠️  Control cohort ratio validation failed:
#    Actual ratio: 0.00:1 (0 controls, 67208 cases)
#    Expected ratio: 5.00:1 (tolerance: 4.00-6.00:1)
#    Will recreate control cohort to achieve 5.00:1 ratio...
#
# [INFO] Creating control cohort with 336040 controls (target: 5.00:1 ratio with 67208 cases)
# [INFO] Running: /home/pgx3874/jupyter-env/bin/python3.11 /home/pgx3874/pgx-analysis/4a_model_data/create_control_cohort_model_data.py --age-band 85-94 --sample-size 336040
# Python script output:
# Traceback (most recent call last):
#   File "/home/pgx3874/pgx-analysis/4a_model_data/create_control_cohort_model_data.py", line 302, in create_control_cohort_model_data
#     raise ValueError(f"Created parquet file is too small ({file_size} bytes), likely empty or corrupted")
# ValueError: Created parquet file is too small (557 bytes), likely empty or corrupted
# [INFO] Found 38 medical files and 3 pharmacy files
# [INFO] Creating control cohort model_events.parquet for non_opioid_non_ed/85-94...
# [INFO] Sampling 336040 control patients (non-opioid, non-ED)
# [ERROR] Failed to create control cohort model_events.parquet: Created parquet file is too small (557 bytes), likely empty or corrupted
# [INFO] Removed partially created file: /mnt/nvme/4a_model_data/cohort_name=non_opioid_non_ed/age_band=85-94/model_events.parquet
# Traceback (most recent call last):
#   File "/home/pgx3874/pgx-analysis/4a_model_data/create_control_cohort_model_data.py", line 369, in <module>
#     main()
#   File "/home/pgx3874/pgx-analysis/4a_model_data/create_control_cohort_model_data.py", line 361, in main
#     create_control_cohort_model_data(
#   File "/home/pgx3874/pgx-analysis/4a_model_data/create_control_cohort_model_data.py", line 302, in create_control_cohort_model_data
#     raise ValueError(f"Created parquet file is too small ({file_size} bytes), likely empty or corrupted")
# ValueError: Created parquet file is too small (557 bytes), likely empty or corrupted
# [ERROR] Python script exited with code: 1
# [WARN] Control cohort creation may have failed. File not found: /mnt/nvme/4a_model_data/cohort_name=non_opioid_non_ed/age_band=85-94/model_events.parquet
# [WARN] Check Python script output above for errors.
#
# ⚠️  Control cohort 'non_opioid_non_ed' model_events.parquet not found.
#    To create it, run:
#    python 4a_model_data/create_control_cohort_model_data.py --age-band 85-94
#
# Combined TARGET + CONTROL sankey_eventlog created.
# # Log of 1133062 events consisting of:
# 67208 cases
# 1133062 instances of 2716 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-31
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 1,133,062 × 8
#    case_id  activity timestamp           group activity_instance_id lifecycle_id
#    <chr>    <chr>    <dttm>              <chr>                <int> <chr>
#  1 1003613… ICD:Unk… 2018-04-16 00:00:00 targ…                    1 complete
#  2 1003613… CPT:863… 2018-04-16 00:00:00 targ…                    2 complete
#  3 1003613… ICD:Unk… 2018-04-16 00:00:00 targ…                    3 complete
#  4 1003613… CPT:827… 2018-04-16 00:00:00 targ…                    4 complete
#  5 1003613… ICD:Unk… 2018-04-16 00:00:00 targ…                    5 complete
#  6 1003613… CPT:992… 2018-04-16 00:00:00 targ…                    6 complete
#  7 1003613… ICD:Unk… 2018-04-16 00:00:00 targ…                    7 complete
#  8 1003613… CPT:841… 2018-04-16 00:00:00 targ…                    8 complete
#  9 1003613… ICD:Unk… 2018-04-16 00:00:00 targ…                    9 complete
# 10 1003613… CPT:827… 2018-04-16 00:00:00 targ…                   10 complete
# # ℹ 1,133,052 more rows
# # ℹ 2 more variables: resource_id <chr>, .order <int>
#
# --- Pre-HCG (before first HCG ICD) analysis ---
# Pre-HCG eventlog summary:
# # Log of 14859 events consisting of:
# 1258 traces
# 1292 cases
# 14859 instances of 651 activities
# 1 resource
# Events occurred from 2016-01-01 until 2018-12-22
#
# # Variables were mapped as follows:
# Case identifier:		case_id
# Activity identifier:		activity
# Resource identifier:		resource_id
# Activity instance identifier:	activity_instance_id
# Timestamp:			timestamp
# Lifecycle transition:		lifecycle_id
#
# # A tibble: 14,859 × 12
#    case_id    activity     timestamp           activity_instance_id lifecycle_id
#    <chr>      <chr>        <dttm>                             <int> <chr>
#  1 1000002279 DRUG:ALPRAZ… 2016-06-13 00:00:00                    1 complete
#  2 1000002279 DRUG:WARFAR… 2016-06-13 00:00:00                    2 complete
#  3 1000002279 DRUG:ALPRAZ… 2016-06-14 00:00:00                    3 complete
#  4 1000002279 DRUG:WARFAR… 2016-06-16 00:00:00                    4 complete
#  5 1000002279 DRUG:GABAPE… 2016-06-16 00:00:00                    5 complete
#  6 1000002279 DRUG:WARFAR… 2016-06-18 00:00:00                    6 complete
#  7 1000002279 DRUG:SERTRA… 2016-06-20 00:00:00                    7 complete
#  8 1000002279 DRUG:POTASS… 2016-06-20 00:00:00                    8 complete
#  9 1000002279 DRUG:METOPR… 2016-06-20 00:00:00                    9 complete
# 10 1000002279 DRUG:HYDROC… 2016-06-22 00:00:00                   10 complete
# # ℹ 14,849 more rows
# # ℹ 7 more variables: resource_id <chr>, .order <int>, target_date <dttm>,
# #   event_index <int>, is_target_event <lgl>, has_target <lgl>,
# #   first_target_index <int>
# Sample pre-HCG drug-only sequences:
# # A tibble: 6 × 2
#   case_id    drug_sequence
#   <chr>      <list>
# 1 1000002279 <chr [58]>
# 2 1000006328 <chr [8]>
# 3 1000015281 <chr [11]>
# 4 1000021013 <chr [15]>
# 5 1000033815 <chr [3]>
# 6 1000038973 <chr [2]>
# Warning: process_map failed: missing value where TRUE/FALSE needed
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_pre_hcg_patient_features_bupar.csv" "s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_pre_hcg_patient_features_bupar.csv"
# Completed 28.0 KiB/28.0 KiB (395.8 KiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_pre_hcg_patient_features_bupar.csv to s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_pre_hcg_patient_features_bupar.csv
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_time_to_hcg_features_bupar.csv" "s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_time_to_hcg_features_bupar.csv"
# Completed 103.2 KiB/103.2 KiB (1007.1 KiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_time_to_hcg_features_bupar.csv to s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_time_to_hcg_features_bupar.csv
#
# --- Target-only global process mining ---
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_traces_bupar.csv" "s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_traces_bupar.csv"
# Completed 1.0 MiB/19.9 MiB (14.1 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/19.9 MiB (25.4 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/19.9 MiB (37.2 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/19.9 MiB (44.2 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/19.9 MiB (53.5 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/19.9 MiB (62.6 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/19.9 MiB (71.2 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/19.9 MiB (80.3 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/19.9 MiB (89.7 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/19.9 MiB (98.3 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/19.9 MiB (106.7 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/19.9 MiB (115.5 MiB/s) with 1 file(s) remaining
# Completed 12.9 MiB/19.9 MiB (122.4 MiB/s) with 1 file(s) remaining
# Completed 13.9 MiB/19.9 MiB (113.2 MiB/s) with 1 file(s) remaining
# Completed 14.9 MiB/19.9 MiB (120.0 MiB/s) with 1 file(s) remaining
# Completed 15.9 MiB/19.9 MiB (126.8 MiB/s) with 1 file(s) remaining
# Completed 16.9 MiB/19.9 MiB (133.7 MiB/s) with 1 file(s) remaining
# Completed 17.9 MiB/19.9 MiB (140.7 MiB/s) with 1 file(s) remaining
# Completed 18.9 MiB/19.9 MiB (147.6 MiB/s) with 1 file(s) remaining
# Completed 19.9 MiB/19.9 MiB (154.4 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_traces_bupar.csv to s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_traces_bupar.csv
# No top sequences found (all sequences are rare)
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_traces_rare_bupar.csv" "s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_traces_rare_bupar.csv"
# Completed 1.0 MiB/20.1 MiB (16.0 MiB/s) with 1 file(s) remaining
# Completed 2.0 MiB/20.1 MiB (27.8 MiB/s) with 1 file(s) remaining
# Completed 3.0 MiB/20.1 MiB (40.7 MiB/s) with 1 file(s) remaining
# Completed 4.0 MiB/20.1 MiB (50.1 MiB/s) with 1 file(s) remaining
# Completed 5.0 MiB/20.1 MiB (61.6 MiB/s) with 1 file(s) remaining
# Completed 6.0 MiB/20.1 MiB (73.0 MiB/s) with 1 file(s) remaining
# Completed 7.0 MiB/20.1 MiB (84.3 MiB/s) with 1 file(s) remaining
# Completed 8.0 MiB/20.1 MiB (95.1 MiB/s) with 1 file(s) remaining
# Completed 9.0 MiB/20.1 MiB (105.9 MiB/s) with 1 file(s) remaining
# Completed 10.0 MiB/20.1 MiB (114.7 MiB/s) with 1 file(s) remaining
# Completed 11.0 MiB/20.1 MiB (97.8 MiB/s) with 1 file(s) remaining
# Completed 12.0 MiB/20.1 MiB (103.8 MiB/s) with 1 file(s) remaining
# Completed 13.0 MiB/20.1 MiB (108.3 MiB/s) with 1 file(s) remaining
# Completed 14.0 MiB/20.1 MiB (116.0 MiB/s) with 1 file(s) remaining
# Completed 15.0 MiB/20.1 MiB (120.4 MiB/s) with 1 file(s) remaining
# Completed 16.0 MiB/20.1 MiB (124.4 MiB/s) with 1 file(s) remaining
# Completed 17.0 MiB/20.1 MiB (128.9 MiB/s) with 1 file(s) remaining
# Completed 18.0 MiB/20.1 MiB (134.3 MiB/s) with 1 file(s) remaining
# Completed 19.0 MiB/20.1 MiB (139.1 MiB/s) with 1 file(s) remaining
# Completed 20.0 MiB/20.1 MiB (143.1 MiB/s) with 1 file(s) remaining
# Completed 20.1 MiB/20.1 MiB (134.8 MiB/s) with 1 file(s) remaining
# upload: 3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_traces_rare_bupar.csv to s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_traces_rare_bupar.csv
# Saved 58001 rare sequences (frequency <= 1)
# Warning: process_matrix failed: missing value where TRUE/FALSE needed
# Uploading to S3 with command:
#   aws s3 cp "/home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_process_matrix_bupar.csv" "s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_process_matrix_bupar.csv"
# upload: 3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_process_matrix_bupar.csv to s3://pgxdatalake/gold/bupar/non_opioid_ed/85-94/non_opioid_ed_85_94_train_target_process_matrix_bupar.csv
# Warning: process_map failed: missing value where TRUE/FALSE needed
# null device
#           1
# Closed PDF device. Base graphics saved to: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_Rplots.pdf
#
# === bupaR analysis for non_opioid_ed 85-94 completed. ===
#
# [WARN] Some expected output files are missing:
#   - /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_pre_f1120_patient_features_bupar.csv
#   - /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_post_f1120_patient_features_bupar.csv
#   - /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/features/non_opioid_ed_85_94_train_target_time_to_f1120_features_bupar.csv
#
# [INFO] Creating post-target analysis CSV...
# [OK] Post-target analysis CSV created successfully
#
# ================================================================================
# Creating BupaR Post-Target Analysis: non_opioid_ed / 85-94
# ================================================================================
#
# [INFO] Using event-level data for post-target leakage analysis
#        This provides accurate pre/post F1120 ratios for each feature
# Loading event data from: /mnt/nvme/4a_model_data/cohort_name=non_opioid_ed/age_band=85-94/model_events.parquet
# [OK] Analyzed 1829 features from event data
#    Features with post-F1120 ratio >= 80% (leakage): 1302
#    Features with pre-F1120 ratio >= 80% (predictive): 89
#    Features with mixed timing: 438
#    Total pre-F1120 events: 24,357.0
#    Total post-F1120 events: 651,481.0
#
# [OK] Saved post-target analysis to: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/non_opioid_ed_85_94_bupar_post_target_analysis.csv
#    Total features analyzed: 1829
#    Post-target leakage features: 1302
#
#    [WARN] Post-target leakage features (post-F1120 ratio >= 80%):
#    ================================================================================
#      item_icd_UNKNOWN                         | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 351866 | Total: 351866
#      item_cpt_97530                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 30574 | Total: 30574
#      item_cpt_97110                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 25771 | Total: 25771
#      item_cpt_97116                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 13404 | Total: 13404
#      item_cpt_92526                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 8872 | Total: 8872
#      item_cpt_97535                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 8510 | Total: 8510
#      item_cpt_97112                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 5983 | Total: 5983
#      item_cpt_85025                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 5201 | Total: 5201
#      item_cpt_80053                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 4277 | Total: 4277
#      item_cpt_36415                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 3972 | Total: 3972
#      item_cpt_G8979                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 3295 | Total: 3295
#      item_cpt_80048                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 3164 | Total: 3164
#      item_cpt_93005                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 3048 | Total: 3048
#      item_cpt_71045                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2965 | Total: 2965
#      item_cpt_84484                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2892 | Total: 2892
#      item_cpt_99285                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2834 | Total: 2834
#      item_cpt_92507                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2786 | Total: 2786
#      item_cpt_G8978                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2632 | Total: 2632
#      item_cpt_97140                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2397 | Total: 2397
#      item_cpt_81001                           | Post: 100.0% | Pre:   0.0% | Pre:    0 | Post: 2371 | Total: 2371
#      ... and 1282 more
#    ================================================================================
#
#    [OK] Pre-target predictive features (pre-F1120 ratio >= 80%):
#    ================================================================================
#      item_drug_PROVENTIL_HFA                  | Pre:  80.0% | Post:  20.0% | Pre:    8 | Post:    2 | Total:   10
#      item_drug_BENICAR                        | Pre:  80.0% | Post:  20.0% | Pre:    8 | Post:    2 | Total:   10
#      item_drug_ACARBOSE                       | Pre:  80.0% | Post:  20.0% | Pre:    8 | Post:    2 | Total:   10
#      item_drug_BD_SWABS_SINGLE_USE            | Pre:  80.0% | Post:  20.0% | Pre:    8 | Post:    2 | Total:   10
#      item_drug_ILEVRO                         | Pre:  80.0% | Post:  20.0% | Pre:    4 | Post:    1 | Total:    5
#      item_drug_QVAR                           | Pre:  80.0% | Post:  20.0% | Pre:    4 | Post:    1 | Total:    5
#      item_drug_SEREVENT_DISKUS                | Pre:  80.0% | Post:  20.0% | Pre:    4 | Post:    1 | Total:    5
#      item_drug_DOXYCYCLINE_MONOHYDRATE        | Pre:  80.8% | Post:  19.2% | Pre:   21 | Post:    5 | Total:   26
#      item_drug_TOLTERODINE_TARTRATE_ER        | Pre:  80.8% | Post:  19.2% | Pre:   21 | Post:    5 | Total:   26
#      item_drug_FLUZONE_HIGH_DOSE_PF_2018      | Pre:  81.2% | Post:  18.8% | Pre:   13 | Post:    3 | Total:   16
#      item_drug_SOTALOL_HCL                    | Pre:  81.5% | Post:  18.5% | Pre:   22 | Post:    5 | Total:   27
#      item_drug_ENTRESTO                       | Pre:  81.8% | Post:  18.2% | Pre:    9 | Post:    2 | Total:   11
#      item_drug_RISPERIDONE                    | Pre:  81.9% | Post:  18.1% | Pre:   86 | Post:   19 | Total:  105
#      item_drug_SSD                            | Pre:  82.4% | Post:  17.6% | Pre:   14 | Post:    3 | Total:   17
#      item_drug_LAMOTRIGINE                    | Pre:  82.6% | Post:  17.4% | Pre:   19 | Post:    4 | Total:   23
#      item_drug_RANITIDINE_HCL                 | Pre:  83.3% | Post:  16.7% | Pre:   35 | Post:    7 | Total:   42
#      item_drug_PROMETHAZINE/DEXTROMETHOR      | Pre:  83.3% | Post:  16.7% | Pre:   10 | Post:    2 | Total:   12
#      item_drug_INDAPAMIDE                     | Pre:  83.3% | Post:  16.7% | Pre:   10 | Post:    2 | Total:   12
#      item_drug_PIOGLITAZONE_HCL               | Pre:  83.3% | Post:  16.7% | Pre:    5 | Post:    1 | Total:    6
#      item_drug_SENNA_LAX                      | Pre:  83.3% | Post:  16.7% | Pre:    5 | Post:    1 | Total:    6
#      ... and 69 more
#    ================================================================================
#
#    Summary Statistics:
#      Mean pre-F1120 ratio: 17.52%
#      Median pre-F1120 ratio: 0.00%
#      Mean post-F1120 ratio: 82.48%
#      Median post-F1120 ratio: 100.00%
#      Features with post-ratio > 50%: 1456
#      Features with post-ratio > 80%: 1294
#      Features with post-ratio > 90%: 1268
#      Features with pre-ratio > 80%: 82
#
#
#
# ✅ BupaR analysis completed successfully

# %% [markdown]
# ### 3. Load and Review BupaR Results

# %%
# Load BupaR results
bupar_results_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_bupar_post_target_analysis.csv"

if bupar_results_path.exists():
    bupar_results = pd.read_csv(bupar_results_path)
    print(f"✅ Loaded BupaR results: {len(bupar_results)} features analyzed")
    
    # Show post-target leakage features
    post_target_leakage = bupar_results[bupar_results.get('is_post_target_leakage', pd.Series([0]*len(bupar_results))) == 1]
    
    print(f"\n📊 BupaR Analysis Summary:")
    print(f"   Total features analyzed: {len(bupar_results)}")
    print(f"   Post-target leakage features: {len(post_target_leakage)}")
    
    if len(post_target_leakage) > 0:
        print(f"\n   ⚠️  Post-target leakage features identified:")
        display(post_target_leakage[['feature', 'is_post_target_leakage']].head(20))
    else:
        print(f"\n   ✅ No post-target leakage features identified")
    
    # Display full results
    print(f"\n   Full BupaR results:")
    display(bupar_results.head(20))
else:
    print(f"❌ BupaR results not found: {bupar_results_path}")
    bupar_results = pd.DataFrame()
# Out:
# ❌ BupaR results not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/non_opioid_ed_85_94_bupar_post_target_analysis.csv

# %% [markdown]
# ### 4. View BupaR Visualizations

# %%
# Display BupaR visualizations
bupar_plots = [
    f"{COHORT}_{AGE_BAND_FNAME}_overall_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_milestones_gantt.png",
    f"{COHORT}_{AGE_BAND_FNAME}_activity_sequence_top.png",
    f"{COHORT}_{AGE_BAND_FNAME}_pre_f1120_activity_frequency.png",
    f"{COHORT}_{AGE_BAND_FNAME}_post_f1120_activity_frequency.png",
]

# Check if plots directory exists and list available plots
if PLOTS_DIR.exists():
    available_plots = list(PLOTS_DIR.glob("*.png"))
    print(f"📁 Plots directory: {PLOTS_DIR}")
    print(f"   Found {len(available_plots)} PNG files")
    if available_plots:
        print(f"   Available plots:")
        for p in sorted(available_plots):
            print(f"     - {p.name}")
else:
    print(f"⚠️  Plots directory does not exist: {PLOTS_DIR}")

print(f"\n🔍 Looking for BupaR plots...")
for plot_name in bupar_plots:
    plot_path = PLOTS_DIR / plot_name
    if plot_path.exists():
        print(f"✅ Displaying: {plot_name}")
        display(Image(str(plot_path)))
    else:
        print(f"⚠️  Plot not found: {plot_path}")
        # Try alternative path (in case plots are in features/ subdirectory)
        alt_path = OUTPUT_DIR / "features" / plot_name
        if alt_path.exists():
            print(f"   Found in alternative location: {alt_path}")
            display(Image(str(alt_path)))
        else:
            # Try without cohort prefix (in case R script saved without it)
            simple_name = plot_name.replace(f"{COHORT}_{AGE_BAND_FNAME}_", "")
            simple_path = PLOTS_DIR / simple_name
            if simple_path.exists():
                print(f"   Found with simple name: {simple_path}")
                display(Image(str(simple_path)))
# Out:
# 📁 Plots directory: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots
#    Found 0 PNG files
#
# 🔍 Looking for BupaR plots...
# ⚠️  Plot not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_overall_activity_frequency.png
# ⚠️  Plot not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_activity_milestones_gantt.png
# ⚠️  Plot not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_activity_sequence_top.png
# ⚠️  Plot not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_pre_f1120_activity_frequency.png
# ⚠️  Plot not found: /home/pgx3874/pgx-analysis/3b_feature_importance_eda/outputs/non_opioid_ed/85_94/plots/non_opioid_ed_85_94_post_f1120_activity_frequency.png

# %% [markdown]
# ## D. Interactive Code Review and Filtering
#
# Review the analysis results and manually add/remove codes that should be filtered before Step 4a.

# %% [markdown]
# ### 1. Review Codes to Filter
#
# Based on the BupaR analyses, review codes that should be filtered:

# %% [markdown]
# ### 2. Manually Add/Remove Codes to Filter
#
# **Instructions:**
# 1. Review the visualizations and analysis results above
# 2. Add codes to filter in the cell below (one per line)
# 3. Remove codes from the filtering list if they should be kept
# 4. Run the cell to update the filtering list

# %%
# ============================================
# MANUAL CODE FILTERING
# ============================================
# Add codes here that you want to filter based on your review
# Format: one code per line as a string
# 
# NOTE: This section is idempotent - it will load existing config if it exists
# and merge new codes with existing ones. Running multiple times is safe.

# Initialize filtering_recommendations if not already defined
# Works in both scripts and notebooks
try:
    # Check if it exists by trying to access it
    _ = filtering_recommendations
except NameError:
    # Doesn't exist, create it
    filtering_recommendations = {
        'administrative_codes': set(),
        'bupar_post_target': set(),
        'manual_additional': set()
    }
    print("ℹ️  Initialized filtering_recommendations with empty sets")


# Load existing config if it exists (idempotency)
filtering_config_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_manual_filtering_config.json"
existing_manual_codes = []
existing_codes_to_keep = []

if filtering_config_path.exists():
    try:
        with open(filtering_config_path, 'r') as f:
            existing_config = json.load(f)
        existing_codes_to_keep = existing_config.get('codes_to_keep', [])
        existing_manual_codes = []
        # Extract manual codes from existing config
        if 'manual_additional_count' in existing_config:
            manual_count = existing_config['manual_additional_count']
            all_codes = existing_config.get('codes_to_filter', [])
            admin_count = existing_config.get('administrative_codes_count', 0)
            bupar_count = existing_config.get('bupar_post_target_count', 0)
            if len(all_codes) > (admin_count + bupar_count):
                start_idx = admin_count + bupar_count
                existing_manual_codes = all_codes[start_idx:]
        print(f"✅ Loaded existing config: {len(existing_manual_codes)} manual codes, {len(existing_codes_to_keep)} codes to keep")
    except Exception as e:
        print(f"⚠️  Could not load existing config: {e}")
        print(f"   Starting with empty lists")

# Default: empty lists (can be overridden by user)
MANUAL_CODES_TO_FILTER = [
    # Example: "Z00.00",  # Administrative code
    # Example: "V70.0",   # Routine exam
    # Add your codes here:
]

# Remove codes from filtering if they should be kept
CODES_TO_KEEP = [
    # Example: "F11.20",  # Keep this code even if flagged
    # Add codes to keep here:
]

# Merge with existing codes (idempotent - union operation)
# Start with existing manual codes, then add new ones
all_manual_codes = set(existing_manual_codes) | set(MANUAL_CODES_TO_FILTER)
all_codes_to_keep = set(existing_codes_to_keep) | set(CODES_TO_KEEP)

# Update filtering recommendations (merge, don't replace)
filtering_recommendations['manual_additional'].update(all_manual_codes)

# Remove codes that should be kept from all categories
for code in all_codes_to_keep:
    filtering_recommendations['administrative_codes'].discard(code)
    filtering_recommendations['bupar_post_target'].discard(code)
    filtering_recommendations['manual_additional'].discard(code)

# Final list of codes to filter (union of all categories)
final_codes_to_filter = (
    filtering_recommendations['administrative_codes'] |
    filtering_recommendations['bupar_post_target'] |
    filtering_recommendations['manual_additional']
)

print(f"✅ Updated filtering list")
print(f"   Total codes to filter: {len(final_codes_to_filter)}")
print(f"     - Administrative codes: {len(filtering_recommendations['administrative_codes'])}")
print(f"     - BupaR post-target codes: {len(filtering_recommendations['bupar_post_target'])}")
print(f"     - Manual additional codes: {len(filtering_recommendations['manual_additional'])}")
print(f"     - Codes to keep: {len(all_codes_to_keep)}")

if len(final_codes_to_filter) > 0:
    print(f"\n   Codes to filter (showing first 50):")
    for code in sorted(list(final_codes_to_filter))[:50]:
        print(f"     - {code}")
    if len(final_codes_to_filter) > 50:
        print(f"     ... and {len(final_codes_to_filter) - 50} more")

# Save filtering list to JSON for use in next step (idempotent - overwrites with complete state)
filtering_config = {
    'codes_to_filter': sorted(list(final_codes_to_filter)),
    'codes_to_keep': sorted(list(all_codes_to_keep)),
    'administrative_codes_count': len(filtering_recommendations['administrative_codes']),
    'bupar_post_target_count': len(filtering_recommendations['bupar_post_target']),
    'manual_additional_count': len(filtering_recommendations['manual_additional'])
}

with open(filtering_config_path, 'w') as f:
    json.dump(filtering_config, f, indent=2)

print(f"\n   💾 Saved filtering config to: {filtering_config_path}")
# Out:
#   Cell In[21], line 21
#     final_codes_to_filter = (
#     ^
# IndentationError: expected an indented block after 'for' statement on line 19

# %% [markdown]
# ### 3. Update Filtering Scripts (if needed)
#
# If you've added manual codes, you may need to update the filtering scripts to include them. Otherwise, proceed to run the filter and refine step.

# %% [markdown]
# ### 4. Run Filter and Refine

# %%
import subprocess
from datetime import datetime

print("🚀 Filtering and Refining Features...")
print(f"Started at: {datetime.now()}")

cmd = [
    str(PYTHON_BIN),
    str(PROJECT_ROOT / "3b_feature_importance_eda" / "filter_and_refine_features.py"),
    "--cohort", COHORT,
    "--age-band", AGE_BAND
]

result = subprocess.run(cmd, cwd=str(PROJECT_ROOT), capture_output=True, text=True)

print(result.stdout)
if result.stderr:
    print("STDERR:", result.stderr)

if result.returncode == 0:
    print(f"\n✅ Filter and refine completed successfully")
else:
    print(f"\n❌ Filter and refine failed with return code {result.returncode}")

# %%
# Load final refined feature importance
refined_fi_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

if refined_fi_path.exists():
    refined_fi = pd.read_csv(refined_fi_path)
    print(f"✅ Loaded refined feature importance: {len(refined_fi)} features")
    
    # Load filtering summary
    summary_path = OUTPUT_DIR / f"{COHORT}_{AGE_BAND_FNAME}_feature_filtering_summary.json"
    if summary_path.exists():
        with open(summary_path, 'r') as f:
            filtering_summary = json.load(f)
        
        print(f"\n📊 Filtering Summary:")
        print(f"   Original features: {filtering_summary.get('original_count', 'N/A')}")
        print(f"   Filtered by post-target: {filtering_summary.get('filtered_by_post_target', 0)}")
        print(f"   Filtered by non-value-added: {filtering_summary.get('filtered_by_non_value_added', 0)}")
        print(f"   Filtered by threshold: {filtering_summary.get('filtered_by_threshold', 0)}")
        print(f"   Final features: {filtering_summary.get('final_count', 'N/A')}")
    
    print(f"\n   Top 20 refined features:")
    display(refined_fi.head(20))
    
    print(f"\n   ✅ File ready for Step 4a: {refined_fi_path}")
else:
    print(f"❌ Refined feature importance not found: {refined_fi_path}")

# %% [markdown]
# ### 5. Verify S3 Upload
#
# Check that the refined feature importance file was uploaded to S3 for Step 4a consumption.

# %%
import boto3

s3_client = boto3.client('s3')
s3_bucket = 'pgxdatalake'
s3_key = f"gold/feature_importance/{COHORT}/{AGE_BAND}/{COHORT}_{AGE_BAND_FNAME}_cohort_feature_importance.csv"

try:
    s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    print(f"✅ File exists in S3: s3://{s3_bucket}/{s3_key}")
    
    # Get file size
    response = s3_client.head_object(Bucket=s3_bucket, Key=s3_key)
    size_mb = response['ContentLength'] / (1024 * 1024)
    print(f"   File size: {size_mb:.2f} MB")
    print(f"   Last modified: {response['LastModified']}")
except s3_client.exceptions.ClientError as e:
    if e.response['Error']['Code'] == '404':
        print(f"❌ File not found in S3: s3://{s3_bucket}/{s3_key}")
    else:
        print(f"❌ Error checking S3: {e}")

# %% [markdown]
# ## Summary
#
# ✅ **Step 3b Interactive Analysis Complete**
#
# **Outputs Generated:**
# - ✅ BupaR post-target analysis results
# - ✅ Refined `cohort_feature_importance.csv` for Step 4a
# - ✅ Filtering summary JSON
# - ✅ Visualizations (BupaR)
#
# **Next Steps:**
# - Proceed to **Step 4a: Model Data Creation** using the refined feature importances
# - The `cohort_feature_importance.csv` file is available locally and in S3
